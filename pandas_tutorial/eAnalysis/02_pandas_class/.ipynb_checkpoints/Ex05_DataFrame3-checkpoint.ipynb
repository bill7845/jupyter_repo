# %% [markdown]
# ##  데이타 분석
#
# 데이타 -> 필터링 -> 정제 -> 시각화 -> 분석
#
#
# ## 데이타 필터링
#
# 분석에 필요한 데이타를 거르는 작업 ( 데이타 추출 )
#
# 1. 열단위 추출 : df['컬럼명']
#
# 2. 행단위 추출 : df.loc[인덱스명칭] / df.iloc[인덱스위치]
#
#     - loc[] : 명칭 기반 인덱싱
#     - iloc[] : 위치 기반 인덱싱
#
#     현재 인덱스가 글자로 지정되지 않았기에 loc[]/iloc[] 모두 가능
#
#
#         - loc과 iloc 차이
#             - df.loc[-1]  # 에러
#             - df.iloc[-1] # 마지막번호

# %%
# 데이타 추출

import pandas as pd

df = pd.read_excel('http://qrc.depaul.edu/excel_files/presidents.xlsx')

# 1. 열단위 추출
# Out:
#                  President  Age at inauguration
# 0        George Washington                   57
# 1               John Adams                   61
# 2         Thomas Jefferson                   57
# 3            James Madison                   57
# 4             James Monroe                   58
# 5        John Quincy Adams                   57
# 6           Andrew Jackson                   61
# 7        Martin Van Buren                    54
# 8   William Henry Harrison                   68
# 9            James K. Polk                   49
# 10          Zachary Taylor                   64
# 11         Franklin Pierce                   48
# 12          James Buchanan                   65
# 13         Abraham Lincoln                   52
# 14        Ulysses S. Grant                   46
# 15     Rutherford B. Hayes                   54
# 16       James A. Garfield                   49
# 17        Grover Cleveland                   47
# 18       Benjamin Harrison                   55
# 19        Grover Cleveland                   55
# 20        William McKinley                   54
# 21     William Howard Taft                   51
# 22          Woodrow Wilson                   56
# 23       Warren G. Harding                   55
# 24          Herbert Hoover                   54
# 25      Franklin Roosevelt                   51
# 26    Dwight D. Eisenhower                   62
# 27         John F. Kennedy                   43
# 28        Richard M. Nixon                   56
# 29            Jimmy Carter                   52
# 30           Ronald Reagan                   69
# 31             George Bush                   64
# 32            Bill Clinton                   46
# 33          George W. Bush                   54
# 34            Barack Obama                   47

# %%
# 2. 행단위 추출
""" 
    loc[] : 명칭 기반 인덱싱
    iloc[] : 위치 기반 인덱싱
    
    현재 인덱스가 글자로 지정되지 않았기에 loc[]/iloc[] 모두 가능
"""
# (1) loc
# Out:
#             President  Years in office  Year first inaugurated  \
# 0   George Washington              8.0                    1789
# 13    Abraham Lincoln              4.0                    1861
# 34       Barack Obama              NaN                    2009
#
#     Age at inauguration State elected from  # of electoral votes  \
# 0                    57           Virginia                    69
# 13                   52           Illinois                   180
# 34                   47           Illinois                   365
#
#    # of popular votes National total votes  Total electoral votes  \
# 0                NA()                 NA()                     69
# 13            1865908              4685561                    303
# 34           69492376            129438754                    538
#
#     Rating points Political Party Occupation              College  \
# 0           842.0            None    Planter                 None
# 13          900.0      Republican     Lawyer                 None
# 34            NaN        Democrat     Lawyer  Columbia University
#
#     % electoral % popular
# 0    100.000000      NA()
# 13    59.405941   39.8225
# 34    67.843866   53.6875

# %%
# (2) iloc
# Out:
# President                 George Washington
# Years in office                           8
# Year first inaugurated                 1789
# Age at inauguration                      57
# State elected from                 Virginia
# # of electoral votes                     69
# # of popular votes                     NA()
# National total votes                   NA()
# Total electoral votes                    69
# Rating points                           842
# Political Party                        None
# Occupation                          Planter
# College                                None
# % electoral                             100
# % popular                              NA()
# Name: 0, dtype: object
# President                 George Washington
# Years in office                           8
# Year first inaugurated                 1789
# Age at inauguration                      57
# State elected from                 Virginia
# # of electoral votes                     69
# # of popular votes                     NA()
# National total votes                   NA()
# Total electoral votes                    69
# Rating points                           842
# Political Party                        None
# Occupation                          Planter
# College                                None
# % electoral                             100
# % popular                              NA()
# Name: 0, dtype: object

# %% [markdown]
# 마지막행의 데이타 추출

# %%
# Out:
#        President  Years in office  Year first inaugurated  \
# 34  Barack Obama              NaN                    2009
#
#     Age at inauguration State elected from  # of electoral votes  \
# 34                   47           Illinois                   365
#
#    # of popular votes National total votes  Total electoral votes  \
# 34           69492376            129438754                    538
#
#     Rating points Political Party Occupation              College  \
# 34            NaN        Democrat     Lawyer  Columbia University
#
#     % electoral % popular
# 34    67.843866   53.6875

# %%
# Out:
#        President  Years in office  Year first inaugurated  \
# 34  Barack Obama              NaN                    2009
#
#     Age at inauguration State elected from  # of electoral votes  \
# 34                   47           Illinois                   365
#
#    # of popular votes National total votes  Total electoral votes  \
# 34           69492376            129438754                    538
#
#     Rating points Political Party Occupation              College  \
# 34            NaN        Democrat     Lawyer  Columbia University
#
#     % electoral % popular
# 34    67.843866   53.6875
# President                        Barack Obama
# Years in office                           NaN
# Year first inaugurated                   2009
# Age at inauguration                        47
# State elected from                   Illinois
# # of electoral votes                      365
# # of popular votes                   69492376
# National total votes                129438754
# Total electoral votes                     538
# Rating points                             NaN
# Political Party                      Democrat
# Occupation                             Lawyer
# College                   Columbia University
# % electoral                           67.8439
# % popular                             53.6875
# Name: 34, dtype: object
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# 행열 모두 지정하여 추출
#
# - 초대 대통령 10명의 이름과 대학을 추출

# %%
# (1) 초대 대통령 10명의 이름과 대학을 추출
#     하지만 컬럼명을 기술하는 것을 권장
# Out:
#                 President           College
# 0       George Washington              None
# 1              John Adams           Harvard
# 2        Thomas Jefferson  William and Mary
# 3           James Madison         Princeton
# 4            James Monroe  William and Mary
# 5       John Quincy Adams           Harvard
# 6          Andrew Jackson              None
# 7       Martin Van Buren               None
# 8  William Henry Harrison    Hampden-Sydney

# %% [markdown]
# ## 추후 미국대통령 데이타셋을 분석하고 정보를 도출하여 출력(시각화 권장)
