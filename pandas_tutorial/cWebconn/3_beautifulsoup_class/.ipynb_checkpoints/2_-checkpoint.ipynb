# %%
"""
    HTML 내부에 있는 링크를 추출하는 함수
        - CSS 파일과 a 링크 연결된 모든 파일을 가져오기
"""

from bs4 import BeautifulSoup
from urllib import parse
from urllib import request

def enum_links(html,base):
    #-------------------------------------
    soup = BeautifulSoup(html,'html.parser')
    links = soup.select('a[href]')
    
    result = []
    for a in links:
        href = a.attrs['href']
        url = parse.urljoin(base,href) ## urljoin 사용
        result.append(url)
    return result


if __name__ == '__main__':
    url = 'https://docs.python.org/3.7/library/'
    response = request.urlopen(url)   # urllib.request.urlopen() : BeautifulSoup을 통해 html 파서할(데이타를 가져올) 대상
    result = enum_links(response, url)
    print(result)
# Out:
# https://docs.python.org/3.7/genindex.html
# https://docs.python.org/3.7/py-modindex.html
# https://docs.python.org/3.7/library/intro.html
# https://docs.python.org/3.7/reference/grammar.html
# https://www.python.org/
# https://docs.python.org/3.7/index.html
# https://docs.python.org/3.7/library/#the-python-standard-library
# https://docs.python.org/3.7/reference/index.html#reference-index
# https://pypi.org
# https://docs.python.org/3.7/library/intro.html
# https://docs.python.org/3.7/library/intro.html#notes-on-availability
# https://docs.python.org/3.7/library/functions.html
# https://docs.python.org/3.7/library/constants.html
# https://docs.python.org/3.7/library/constants.html#constants-added-by-the-site-module
# https://docs.python.org/3.7/library/stdtypes.html
# https://docs.python.org/3.7/library/stdtypes.html#truth-value-testing
# https://docs.python.org/3.7/library/stdtypes.html#boolean-operations-and-or-not
# https://docs.python.org/3.7/library/stdtypes.html#comparisons
# https://docs.python.org/3.7/library/stdtypes.html#numeric-types-int-float-complex
# https://docs.python.org/3.7/library/stdtypes.html#iterator-types
# https://docs.python.org/3.7/library/stdtypes.html#sequence-types-list-tuple-range
# https://docs.python.org/3.7/library/stdtypes.html#text-sequence-type-str
# https://docs.python.org/3.7/library/stdtypes.html#binary-sequence-types-bytes-bytearray-memoryview
# https://docs.python.org/3.7/library/stdtypes.html#set-types-set-frozenset
# https://docs.python.org/3.7/library/stdtypes.html#mapping-types-dict
# https://docs.python.org/3.7/library/stdtypes.html#context-manager-types
# https://docs.python.org/3.7/library/stdtypes.html#other-built-in-types
# https://docs.python.org/3.7/library/stdtypes.html#special-attributes
# https://docs.python.org/3.7/library/exceptions.html
# https://docs.python.org/3.7/library/exceptions.html#base-classes
# https://docs.python.org/3.7/library/exceptions.html#concrete-exceptions
# https://docs.python.org/3.7/library/exceptions.html#warnings
# https://docs.python.org/3.7/library/exceptions.html#exception-hierarchy
# https://docs.python.org/3.7/library/text.html
# https://docs.python.org/3.7/library/string.html
# https://docs.python.org/3.7/library/re.html
# https://docs.python.org/3.7/library/difflib.html
# https://docs.python.org/3.7/library/textwrap.html
# https://docs.python.org/3.7/library/unicodedata.html
# https://docs.python.org/3.7/library/stringprep.html
# https://docs.python.org/3.7/library/readline.html
# https://docs.python.org/3.7/library/rlcompleter.html
# https://docs.python.org/3.7/library/binary.html
# https://docs.python.org/3.7/library/struct.html
# https://docs.python.org/3.7/library/codecs.html
# https://docs.python.org/3.7/library/datatypes.html
# https://docs.python.org/3.7/library/datetime.html
# https://docs.python.org/3.7/library/calendar.html
# https://docs.python.org/3.7/library/collections.html
# https://docs.python.org/3.7/library/collections.abc.html
# https://docs.python.org/3.7/library/heapq.html
# https://docs.python.org/3.7/library/bisect.html
# https://docs.python.org/3.7/library/array.html
# https://docs.python.org/3.7/library/weakref.html
# https://docs.python.org/3.7/library/types.html
# https://docs.python.org/3.7/library/copy.html
# https://docs.python.org/3.7/library/pprint.html
# https://docs.python.org/3.7/library/reprlib.html
# https://docs.python.org/3.7/library/enum.html
# https://docs.python.org/3.7/library/numeric.html
# https://docs.python.org/3.7/library/numbers.html
# https://docs.python.org/3.7/library/math.html
# https://docs.python.org/3.7/library/cmath.html
# https://docs.python.org/3.7/library/decimal.html
# https://docs.python.org/3.7/library/fractions.html
# https://docs.python.org/3.7/library/random.html
# https://docs.python.org/3.7/library/statistics.html
# https://docs.python.org/3.7/library/functional.html
# https://docs.python.org/3.7/library/itertools.html
# https://docs.python.org/3.7/library/functools.html
# https://docs.python.org/3.7/library/operator.html
# https://docs.python.org/3.7/library/filesys.html
# https://docs.python.org/3.7/library/pathlib.html
# https://docs.python.org/3.7/library/os.path.html
# https://docs.python.org/3.7/library/fileinput.html
# https://docs.python.org/3.7/library/stat.html
# https://docs.python.org/3.7/library/filecmp.html
# https://docs.python.org/3.7/library/tempfile.html
# https://docs.python.org/3.7/library/glob.html
# https://docs.python.org/3.7/library/fnmatch.html
# https://docs.python.org/3.7/library/linecache.html
# https://docs.python.org/3.7/library/shutil.html
# https://docs.python.org/3.7/library/macpath.html
# https://docs.python.org/3.7/library/persistence.html
# https://docs.python.org/3.7/library/pickle.html
# https://docs.python.org/3.7/library/copyreg.html
# https://docs.python.org/3.7/library/shelve.html
# https://docs.python.org/3.7/library/marshal.html
# https://docs.python.org/3.7/library/dbm.html
# https://docs.python.org/3.7/library/sqlite3.html
# https://docs.python.org/3.7/library/archiving.html
# https://docs.python.org/3.7/library/zlib.html
# https://docs.python.org/3.7/library/gzip.html
# https://docs.python.org/3.7/library/bz2.html
# https://docs.python.org/3.7/library/lzma.html
# https://docs.python.org/3.7/library/zipfile.html
# https://docs.python.org/3.7/library/tarfile.html
# https://docs.python.org/3.7/library/fileformats.html
# https://docs.python.org/3.7/library/csv.html
# https://docs.python.org/3.7/library/configparser.html
# https://docs.python.org/3.7/library/netrc.html
# https://docs.python.org/3.7/library/xdrlib.html
# https://docs.python.org/3.7/library/plistlib.html
# https://docs.python.org/3.7/library/crypto.html
# https://docs.python.org/3.7/library/hashlib.html
# https://docs.python.org/3.7/library/hmac.html
# https://docs.python.org/3.7/library/secrets.html
# https://docs.python.org/3.7/library/allos.html
# https://docs.python.org/3.7/library/os.html
# https://docs.python.org/3.7/library/io.html
# https://docs.python.org/3.7/library/time.html
# https://docs.python.org/3.7/library/argparse.html
# https://docs.python.org/3.7/library/getopt.html
# https://docs.python.org/3.7/library/logging.html
# https://docs.python.org/3.7/library/logging.config.html
# https://docs.python.org/3.7/library/logging.handlers.html
# https://docs.python.org/3.7/library/getpass.html
# https://docs.python.org/3.7/library/curses.html
# https://docs.python.org/3.7/library/curses.html#module-curses.textpad
# https://docs.python.org/3.7/library/curses.ascii.html
# https://docs.python.org/3.7/library/curses.panel.html
# https://docs.python.org/3.7/library/platform.html
# https://docs.python.org/3.7/library/errno.html
# https://docs.python.org/3.7/library/ctypes.html
# https://docs.python.org/3.7/library/concurrency.html
# https://docs.python.org/3.7/library/threading.html
# https://docs.python.org/3.7/library/multiprocessing.html
# https://docs.python.org/3.7/library/concurrent.html
# https://docs.python.org/3.7/library/concurrent.futures.html
# https://docs.python.org/3.7/library/subprocess.html
# https://docs.python.org/3.7/library/sched.html
# https://docs.python.org/3.7/library/queue.html
# https://docs.python.org/3.7/library/_thread.html
# https://docs.python.org/3.7/library/_dummy_thread.html
# https://docs.python.org/3.7/library/dummy_threading.html
# https://docs.python.org/3.7/library/contextvars.html
# https://docs.python.org/3.7/library/contextvars.html#context-variables
# https://docs.python.org/3.7/library/contextvars.html#manual-context-management
# https://docs.python.org/3.7/library/contextvars.html#asyncio-support
# https://docs.python.org/3.7/library/ipc.html
# https://docs.python.org/3.7/library/asyncio.html
# https://docs.python.org/3.7/library/socket.html
# https://docs.python.org/3.7/library/ssl.html
# https://docs.python.org/3.7/library/select.html
# https://docs.python.org/3.7/library/selectors.html
# https://docs.python.org/3.7/library/asyncore.html
# https://docs.python.org/3.7/library/asynchat.html
# https://docs.python.org/3.7/library/signal.html
# https://docs.python.org/3.7/library/mmap.html
# https://docs.python.org/3.7/library/netdata.html
# https://docs.python.org/3.7/library/email.html
# https://docs.python.org/3.7/library/json.html
# https://docs.python.org/3.7/library/mailcap.html
# https://docs.python.org/3.7/library/mailbox.html
# https://docs.python.org/3.7/library/mimetypes.html
# https://docs.python.org/3.7/library/base64.html
# https://docs.python.org/3.7/library/binhex.html
# https://docs.python.org/3.7/library/binascii.html
# https://docs.python.org/3.7/library/quopri.html
# https://docs.python.org/3.7/library/uu.html
# https://docs.python.org/3.7/library/markup.html
# https://docs.python.org/3.7/library/html.html
# https://docs.python.org/3.7/library/html.parser.html
# https://docs.python.org/3.7/library/html.entities.html
# https://docs.python.org/3.7/library/xml.html
# https://docs.python.org/3.7/library/xml.etree.elementtree.html
# https://docs.python.org/3.7/library/xml.dom.html
# https://docs.python.org/3.7/library/xml.dom.minidom.html
# https://docs.python.org/3.7/library/xml.dom.pulldom.html
# https://docs.python.org/3.7/library/xml.sax.html
# https://docs.python.org/3.7/library/xml.sax.handler.html
# https://docs.python.org/3.7/library/xml.sax.utils.html
# https://docs.python.org/3.7/library/xml.sax.reader.html
# https://docs.python.org/3.7/library/pyexpat.html
# https://docs.python.org/3.7/library/internet.html
# https://docs.python.org/3.7/library/webbrowser.html
# https://docs.python.org/3.7/library/cgi.html
# https://docs.python.org/3.7/library/cgitb.html
# https://docs.python.org/3.7/library/wsgiref.html
# https://docs.python.org/3.7/library/urllib.html
# https://docs.python.org/3.7/library/urllib.request.html
# https://docs.python.org/3.7/library/urllib.request.html#module-urllib.response
# https://docs.python.org/3.7/library/urllib.parse.html
# https://docs.python.org/3.7/library/urllib.error.html
# https://docs.python.org/3.7/library/urllib.robotparser.html
# https://docs.python.org/3.7/library/http.html
# https://docs.python.org/3.7/library/http.client.html
# https://docs.python.org/3.7/library/ftplib.html
# https://docs.python.org/3.7/library/poplib.html
# https://docs.python.org/3.7/library/imaplib.html
# https://docs.python.org/3.7/library/nntplib.html
# https://docs.python.org/3.7/library/smtplib.html
# https://docs.python.org/3.7/library/smtpd.html
# https://docs.python.org/3.7/library/telnetlib.html
# https://docs.python.org/3.7/library/uuid.html
# https://docs.python.org/3.7/library/socketserver.html
# https://docs.python.org/3.7/library/http.server.html
# https://docs.python.org/3.7/library/http.cookies.html
# https://docs.python.org/3.7/library/http.cookiejar.html
# https://docs.python.org/3.7/library/xmlrpc.html
# https://docs.python.org/3.7/library/xmlrpc.client.html
# https://docs.python.org/3.7/library/xmlrpc.server.html
# https://docs.python.org/3.7/library/ipaddress.html
# https://docs.python.org/3.7/library/mm.html
# https://docs.python.org/3.7/library/audioop.html
# https://docs.python.org/3.7/library/aifc.html
# https://docs.python.org/3.7/library/sunau.html
# https://docs.python.org/3.7/library/wave.html
# https://docs.python.org/3.7/library/chunk.html
# https://docs.python.org/3.7/library/colorsys.html
# https://docs.python.org/3.7/library/imghdr.html
# https://docs.python.org/3.7/library/sndhdr.html
# https://docs.python.org/3.7/library/ossaudiodev.html
# https://docs.python.org/3.7/library/i18n.html
# https://docs.python.org/3.7/library/gettext.html
# https://docs.python.org/3.7/library/locale.html
# https://docs.python.org/3.7/library/frameworks.html
# https://docs.python.org/3.7/library/turtle.html
# https://docs.python.org/3.7/library/cmd.html
# https://docs.python.org/3.7/library/shlex.html
# https://docs.python.org/3.7/library/tk.html
# https://docs.python.org/3.7/library/tkinter.html
# https://docs.python.org/3.7/library/tkinter.ttk.html
# https://docs.python.org/3.7/library/tkinter.tix.html
# https://docs.python.org/3.7/library/tkinter.scrolledtext.html
# https://docs.python.org/3.7/library/idle.html
# https://docs.python.org/3.7/library/othergui.html
# https://docs.python.org/3.7/library/development.html
# https://docs.python.org/3.7/library/typing.html
# https://docs.python.org/3.7/library/pydoc.html
# https://docs.python.org/3.7/library/doctest.html
# https://docs.python.org/3.7/library/unittest.html
# https://docs.python.org/3.7/library/unittest.mock.html
# https://docs.python.org/3.7/library/unittest.mock-examples.html
# https://docs.python.org/3.7/library/2to3.html
# https://docs.python.org/3.7/library/test.html
# https://docs.python.org/3.7/library/test.html#module-test.support
# https://docs.python.org/3.7/library/test.html#module-test.support.script_helper
# https://docs.python.org/3.7/library/debug.html
# https://docs.python.org/3.7/library/bdb.html
# https://docs.python.org/3.7/library/faulthandler.html
# https://docs.python.org/3.7/library/pdb.html
# https://docs.python.org/3.7/library/profile.html
# https://docs.python.org/3.7/library/timeit.html
# https://docs.python.org/3.7/library/trace.html
# https://docs.python.org/3.7/library/tracemalloc.html
# https://docs.python.org/3.7/library/distribution.html
# https://docs.python.org/3.7/library/distutils.html
# https://docs.python.org/3.7/library/ensurepip.html
# https://docs.python.org/3.7/library/venv.html
# https://docs.python.org/3.7/library/zipapp.html
# https://docs.python.org/3.7/library/python.html
# https://docs.python.org/3.7/library/sys.html
# https://docs.python.org/3.7/library/sysconfig.html
# https://docs.python.org/3.7/library/builtins.html
# https://docs.python.org/3.7/library/__main__.html
# https://docs.python.org/3.7/library/warnings.html
# https://docs.python.org/3.7/library/dataclasses.html
# https://docs.python.org/3.7/library/contextlib.html
# https://docs.python.org/3.7/library/abc.html
# https://docs.python.org/3.7/library/atexit.html
# https://docs.python.org/3.7/library/traceback.html
# https://docs.python.org/3.7/library/__future__.html
# https://docs.python.org/3.7/library/gc.html
# https://docs.python.org/3.7/library/inspect.html
# https://docs.python.org/3.7/library/site.html
# https://docs.python.org/3.7/library/custominterp.html
# https://docs.python.org/3.7/library/code.html
# https://docs.python.org/3.7/library/codeop.html
# https://docs.python.org/3.7/library/modules.html
# https://docs.python.org/3.7/library/zipimport.html
# https://docs.python.org/3.7/library/pkgutil.html
# https://docs.python.org/3.7/library/modulefinder.html
# https://docs.python.org/3.7/library/runpy.html
# https://docs.python.org/3.7/library/importlib.html
# https://docs.python.org/3.7/library/language.html
# https://docs.python.org/3.7/library/parser.html
# https://docs.python.org/3.7/library/ast.html
# https://docs.python.org/3.7/library/symtable.html
# https://docs.python.org/3.7/library/symbol.html
# https://docs.python.org/3.7/library/token.html
# https://docs.python.org/3.7/library/keyword.html
# https://docs.python.org/3.7/library/tokenize.html
# https://docs.python.org/3.7/library/tabnanny.html
# https://docs.python.org/3.7/library/pyclbr.html
# https://docs.python.org/3.7/library/py_compile.html
# https://docs.python.org/3.7/library/compileall.html
# https://docs.python.org/3.7/library/dis.html
# https://docs.python.org/3.7/library/pickletools.html
# https://docs.python.org/3.7/library/misc.html
# https://docs.python.org/3.7/library/formatter.html
# https://docs.python.org/3.7/library/windows.html
# https://docs.python.org/3.7/library/msilib.html
# https://docs.python.org/3.7/library/msvcrt.html
# https://docs.python.org/3.7/library/winreg.html
# https://docs.python.org/3.7/library/winsound.html
# https://docs.python.org/3.7/library/unix.html
# https://docs.python.org/3.7/library/posix.html
# https://docs.python.org/3.7/library/pwd.html
# https://docs.python.org/3.7/library/spwd.html
# https://docs.python.org/3.7/library/grp.html
# https://docs.python.org/3.7/library/crypt.html
# https://docs.python.org/3.7/library/termios.html
# https://docs.python.org/3.7/library/tty.html
# https://docs.python.org/3.7/library/pty.html
# https://docs.python.org/3.7/library/fcntl.html
# https://docs.python.org/3.7/library/pipes.html
# https://docs.python.org/3.7/library/resource.html
# https://docs.python.org/3.7/library/nis.html
# https://docs.python.org/3.7/library/syslog.html
# https://docs.python.org/3.7/library/superseded.html
# https://docs.python.org/3.7/library/optparse.html
# https://docs.python.org/3.7/library/imp.html
# https://docs.python.org/3.7/library/undoc.html
# https://docs.python.org/3.7/library/undoc.html#platform-specific-modules
# https://docs.python.org/3.7/reference/grammar.html
# https://docs.python.org/3.7/library/intro.html
# https://docs.python.org/3.7/bugs.html
# https://github.com/python/cpython/blob/3.7/Doc/library/index.rst
# https://docs.python.org/3.7/genindex.html
# https://docs.python.org/3.7/py-modindex.html
# https://docs.python.org/3.7/library/intro.html
# https://docs.python.org/3.7/reference/grammar.html
# https://www.python.org/
# https://docs.python.org/3.7/index.html
# https://docs.python.org/3.7/copyright.html
# https://www.python.org/psf/donations/
# https://docs.python.org/3.7/bugs.html
# http://sphinx.pocoo.org/
# []

# %%
"""
    파일을 다운받고 저장하는 함수

     [참고] 파이썬 정규식 표현 : https://wikidocs.net/4308
"""
from bs4 import BeautifulSoup
from urllib import parse
from urllib import request
import os, time, re  # re : 정규식

def download_file(url):
    p = parse.urlparse(url)
    print('1-',p)
    savepath = './' + p.netloc + p.path
    print('2-', savepath)
    
#   '/'로 끝나서 파일명이 없는 경우 index.html을 붙여줌  
    if re.search('/$',savepath):
        savepath += 'index.html'
        print('3-',savepath)
    
#   해당경로에 파일이 있으면 다운로드 받지 않고 리턴 
    if os.path.exists(savepath):
        return savepath
    
#   해당경로의 디렉토리가 없으면 디렉토리 생성
    savedir = os.path.dirname(savepath)
    if not os.path.exists(savedir):
        os.makedirs(savedir) # makedirs => 히위 한번에 생성
    
#   웹페이지 다운받기
    try:
        request.urlretrieve(url,savepath)
        time.sleep(1)
        return savepath
    except:
        print('download failed : ', url)
        return None
        
    
    
if __name__ == '__main__':
    url = 'https://docs.python.org/3.6/library/'
    result = download_file(url)
    print(result)
# Out:
# 1- ParseResult(scheme='https', netloc='docs.python.org', path='/3.6/library/', params='', query='', fragment='')
# 2- ./docs.python.org/3.6/library/
# 3- ./docs.python.org/3.6/library/index.html
# ./docs.python.org/3.6/library/index.html

# %%
"""
    파이썬은 파일하나를 모듈로 취급한다면 다른 파일의 함수를 복사하지 않고 바로 호출한다.

    [주의] import Ex07_alldown1 코드부터 에러발생하지만 실행은 됨

"""


from bs4 import BeautifulSoup
from urllib.parse import *
from urllib.request import *
import os, time, re

# 에러 발생해도 실행은됨
import Ex07_alldown1
import Ex07_alldown2


# 이미 처리한 파일인지 확인하기 위한 변수
proc_files = {}

# HTML을 다운받고 분석하는 함수
def analyze_html(url, root_url):
    # ------------------------------------------------------
    savepath = download_file(url)
    if savepath is None:
        return
    if savepath in proc_files : 
        return
    proc_files[savepath] = True
#   print(proc_files)
    
    f = open(savepath,'r',encoding='utf-8')
    html = f.read()
    links = enum_links(html,url)
#     print(links)
    for url_link in links:
        if url_link.find(root_url) != 0 :
            continue
        if re.search(".html$",url_link):
            analyze_html(url_link,root_url) # 재귀호출
            continue
        download_file(url_link)
    
if __name__ == "__main__":
    # URL에 있는 모든 것 다운받기
    url = "https://docs.python.org/3.5/library/"
    analyze_html(url, url)
# Out:
# 1- ParseResult(scheme='https', netloc='docs.python.org', path='/3.5/library/', params='', query='', fragment='')
# 2- ./docs.python.org/3.5/library/
# 3- ./docs.python.org/3.5/library/index.html
# https://docs.python.org/3.5/genindex.html
# https://docs.python.org/3.5/py-modindex.html
# https://docs.python.org/3.5/library/intro.html
# https://docs.python.org/3.5/reference/grammar.html
# https://www.python.org/
# https://docs.python.org/3.5/index.html
# https://docs.python.org/3.5/library/#the-python-standard-library
# https://docs.python.org/3.5/reference/index.html#reference-index
# https://pypi.python.org/pypi
# https://docs.python.org/3.5/library/intro.html
# https://docs.python.org/3.5/library/functions.html
# https://docs.python.org/3.5/library/constants.html
# https://docs.python.org/3.5/library/constants.html#constants-added-by-the-site-module
# https://docs.python.org/3.5/library/stdtypes.html
# https://docs.python.org/3.5/library/stdtypes.html#truth-value-testing
# https://docs.python.org/3.5/library/stdtypes.html#boolean-operations-and-or-not
# https://docs.python.org/3.5/library/stdtypes.html#comparisons
# https://docs.python.org/3.5/library/stdtypes.html#numeric-types-int-float-complex
# https://docs.python.org/3.5/library/stdtypes.html#iterator-types
# https://docs.python.org/3.5/library/stdtypes.html#sequence-types-list-tuple-range
# https://docs.python.org/3.5/library/stdtypes.html#text-sequence-type-str
# https://docs.python.org/3.5/library/stdtypes.html#binary-sequence-types-bytes-bytearray-memoryview
# https://docs.python.org/3.5/library/stdtypes.html#set-types-set-frozenset
# https://docs.python.org/3.5/library/stdtypes.html#mapping-types-dict
# https://docs.python.org/3.5/library/stdtypes.html#context-manager-types
# https://docs.python.org/3.5/library/stdtypes.html#other-built-in-types
# https://docs.python.org/3.5/library/stdtypes.html#special-attributes
# https://docs.python.org/3.5/library/exceptions.html
# https://docs.python.org/3.5/library/exceptions.html#base-classes
# https://docs.python.org/3.5/library/exceptions.html#concrete-exceptions
# https://docs.python.org/3.5/library/exceptions.html#warnings
# https://docs.python.org/3.5/library/exceptions.html#exception-hierarchy
# https://docs.python.org/3.5/library/text.html
# https://docs.python.org/3.5/library/string.html
# https://docs.python.org/3.5/library/re.html
# https://docs.python.org/3.5/library/difflib.html
# https://docs.python.org/3.5/library/textwrap.html
# https://docs.python.org/3.5/library/unicodedata.html
# https://docs.python.org/3.5/library/stringprep.html
# https://docs.python.org/3.5/library/readline.html
# https://docs.python.org/3.5/library/rlcompleter.html
# https://docs.python.org/3.5/library/binary.html
# https://docs.python.org/3.5/library/struct.html
# https://docs.python.org/3.5/library/codecs.html
# https://docs.python.org/3.5/library/datatypes.html
# https://docs.python.org/3.5/library/datetime.html
# https://docs.python.org/3.5/library/calendar.html
# https://docs.python.org/3.5/library/collections.html
# https://docs.python.org/3.5/library/collections.abc.html
# https://docs.python.org/3.5/library/heapq.html
# https://docs.python.org/3.5/library/bisect.html
# https://docs.python.org/3.5/library/array.html
# https://docs.python.org/3.5/library/weakref.html
# https://docs.python.org/3.5/library/types.html
# https://docs.python.org/3.5/library/copy.html
# https://docs.python.org/3.5/library/pprint.html
# https://docs.python.org/3.5/library/reprlib.html
# https://docs.python.org/3.5/library/enum.html
# https://docs.python.org/3.5/library/numeric.html
# https://docs.python.org/3.5/library/numbers.html
# https://docs.python.org/3.5/library/math.html
# https://docs.python.org/3.5/library/cmath.html
# https://docs.python.org/3.5/library/decimal.html
# https://docs.python.org/3.5/library/fractions.html
# https://docs.python.org/3.5/library/random.html
# https://docs.python.org/3.5/library/statistics.html
# https://docs.python.org/3.5/library/functional.html
# https://docs.python.org/3.5/library/itertools.html
# https://docs.python.org/3.5/library/functools.html
# https://docs.python.org/3.5/library/operator.html
# https://docs.python.org/3.5/library/filesys.html
# https://docs.python.org/3.5/library/pathlib.html
# https://docs.python.org/3.5/library/os.path.html
# https://docs.python.org/3.5/library/fileinput.html
# https://docs.python.org/3.5/library/stat.html
# https://docs.python.org/3.5/library/filecmp.html
# https://docs.python.org/3.5/library/tempfile.html
# https://docs.python.org/3.5/library/glob.html
# https://docs.python.org/3.5/library/fnmatch.html
# https://docs.python.org/3.5/library/linecache.html
# https://docs.python.org/3.5/library/shutil.html
# https://docs.python.org/3.5/library/macpath.html
# https://docs.python.org/3.5/library/persistence.html
# https://docs.python.org/3.5/library/pickle.html
# https://docs.python.org/3.5/library/copyreg.html
# https://docs.python.org/3.5/library/shelve.html
# https://docs.python.org/3.5/library/marshal.html
# https://docs.python.org/3.5/library/dbm.html
# https://docs.python.org/3.5/library/sqlite3.html
# https://docs.python.org/3.5/library/archiving.html
# https://docs.python.org/3.5/library/zlib.html
# https://docs.python.org/3.5/library/gzip.html
# https://docs.python.org/3.5/library/bz2.html
# https://docs.python.org/3.5/library/lzma.html
# https://docs.python.org/3.5/library/zipfile.html
# https://docs.python.org/3.5/library/tarfile.html
# https://docs.python.org/3.5/library/fileformats.html
# https://docs.python.org/3.5/library/csv.html
# https://docs.python.org/3.5/library/configparser.html
# https://docs.python.org/3.5/library/netrc.html
# https://docs.python.org/3.5/library/xdrlib.html
# https://docs.python.org/3.5/library/plistlib.html
# https://docs.python.org/3.5/library/crypto.html
# https://docs.python.org/3.5/library/hashlib.html
# https://docs.python.org/3.5/library/hmac.html
# https://docs.python.org/3.5/library/allos.html
# https://docs.python.org/3.5/library/os.html
# https://docs.python.org/3.5/library/io.html
# https://docs.python.org/3.5/library/time.html
# https://docs.python.org/3.5/library/argparse.html
# https://docs.python.org/3.5/library/getopt.html
# https://docs.python.org/3.5/library/logging.html
# https://docs.python.org/3.5/library/logging.config.html
# https://docs.python.org/3.5/library/logging.handlers.html
# https://docs.python.org/3.5/library/getpass.html
# https://docs.python.org/3.5/library/curses.html
# https://docs.python.org/3.5/library/curses.html#module-curses.textpad
# https://docs.python.org/3.5/library/curses.ascii.html
# https://docs.python.org/3.5/library/curses.panel.html
# https://docs.python.org/3.5/library/platform.html
# https://docs.python.org/3.5/library/errno.html
# https://docs.python.org/3.5/library/ctypes.html
# https://docs.python.org/3.5/library/concurrency.html
# https://docs.python.org/3.5/library/threading.html
# https://docs.python.org/3.5/library/multiprocessing.html
# https://docs.python.org/3.5/library/concurrent.html
# https://docs.python.org/3.5/library/concurrent.futures.html
# https://docs.python.org/3.5/library/subprocess.html
# https://docs.python.org/3.5/library/sched.html
# https://docs.python.org/3.5/library/queue.html
# https://docs.python.org/3.5/library/dummy_threading.html
# https://docs.python.org/3.5/library/_thread.html
# https://docs.python.org/3.5/library/_dummy_thread.html
# https://docs.python.org/3.5/library/ipc.html
# https://docs.python.org/3.5/library/socket.html
# https://docs.python.org/3.5/library/ssl.html
# https://docs.python.org/3.5/library/select.html
# https://docs.python.org/3.5/library/selectors.html
# https://docs.python.org/3.5/library/asyncio.html
# https://docs.python.org/3.5/library/asyncore.html
# https://docs.python.org/3.5/library/asynchat.html
# https://docs.python.org/3.5/library/signal.html
# https://docs.python.org/3.5/library/mmap.html
# https://docs.python.org/3.5/library/netdata.html
# https://docs.python.org/3.5/library/email.html
# https://docs.python.org/3.5/library/json.html
# https://docs.python.org/3.5/library/mailcap.html
# https://docs.python.org/3.5/library/mailbox.html
# https://docs.python.org/3.5/library/mimetypes.html
# https://docs.python.org/3.5/library/base64.html
# https://docs.python.org/3.5/library/binhex.html
# https://docs.python.org/3.5/library/binascii.html
# https://docs.python.org/3.5/library/quopri.html
# https://docs.python.org/3.5/library/uu.html
# https://docs.python.org/3.5/library/markup.html
# https://docs.python.org/3.5/library/html.html
# https://docs.python.org/3.5/library/html.parser.html
# https://docs.python.org/3.5/library/html.entities.html
# https://docs.python.org/3.5/library/xml.html
# https://docs.python.org/3.5/library/xml.etree.elementtree.html
# https://docs.python.org/3.5/library/xml.dom.html
# https://docs.python.org/3.5/library/xml.dom.minidom.html
# https://docs.python.org/3.5/library/xml.dom.pulldom.html
# https://docs.python.org/3.5/library/xml.sax.html
# https://docs.python.org/3.5/library/xml.sax.handler.html
# https://docs.python.org/3.5/library/xml.sax.utils.html
# https://docs.python.org/3.5/library/xml.sax.reader.html
# https://docs.python.org/3.5/library/pyexpat.html
# https://docs.python.org/3.5/library/internet.html
# https://docs.python.org/3.5/library/webbrowser.html
# https://docs.python.org/3.5/library/cgi.html
# https://docs.python.org/3.5/library/cgitb.html
# https://docs.python.org/3.5/library/wsgiref.html
# https://docs.python.org/3.5/library/urllib.html
# https://docs.python.org/3.5/library/urllib.request.html
# https://docs.python.org/3.5/library/urllib.request.html#module-urllib.response
# https://docs.python.org/3.5/library/urllib.parse.html
# https://docs.python.org/3.5/library/urllib.error.html
# https://docs.python.org/3.5/library/urllib.robotparser.html
# https://docs.python.org/3.5/library/http.html
# https://docs.python.org/3.5/library/http.client.html
# https://docs.python.org/3.5/library/ftplib.html
# https://docs.python.org/3.5/library/poplib.html
# https://docs.python.org/3.5/library/imaplib.html
# https://docs.python.org/3.5/library/nntplib.html
# https://docs.python.org/3.5/library/smtplib.html
# https://docs.python.org/3.5/library/smtpd.html
# https://docs.python.org/3.5/library/telnetlib.html
# https://docs.python.org/3.5/library/uuid.html
# https://docs.python.org/3.5/library/socketserver.html
# https://docs.python.org/3.5/library/http.server.html
# https://docs.python.org/3.5/library/http.cookies.html
# https://docs.python.org/3.5/library/http.cookiejar.html
# https://docs.python.org/3.5/library/xmlrpc.html
# https://docs.python.org/3.5/library/xmlrpc.client.html
# https://docs.python.org/3.5/library/xmlrpc.server.html
# https://docs.python.org/3.5/library/ipaddress.html
# https://docs.python.org/3.5/library/mm.html
# https://docs.python.org/3.5/library/audioop.html
# https://docs.python.org/3.5/library/aifc.html
# https://docs.python.org/3.5/library/sunau.html
# https://docs.python.org/3.5/library/wave.html
# https://docs.python.org/3.5/library/chunk.html
# https://docs.python.org/3.5/library/colorsys.html
# https://docs.python.org/3.5/library/imghdr.html
# https://docs.python.org/3.5/library/sndhdr.html
# https://docs.python.org/3.5/library/ossaudiodev.html
# https://docs.python.org/3.5/library/i18n.html
# https://docs.python.org/3.5/library/gettext.html
# https://docs.python.org/3.5/library/locale.html
# https://docs.python.org/3.5/library/frameworks.html
# https://docs.python.org/3.5/library/turtle.html
# https://docs.python.org/3.5/library/cmd.html
# https://docs.python.org/3.5/library/shlex.html
# https://docs.python.org/3.5/library/tk.html
# https://docs.python.org/3.5/library/tkinter.html
# https://docs.python.org/3.5/library/tkinter.ttk.html
# https://docs.python.org/3.5/library/tkinter.tix.html
# https://docs.python.org/3.5/library/tkinter.scrolledtext.html
# https://docs.python.org/3.5/library/idle.html
# https://docs.python.org/3.5/library/othergui.html
# https://docs.python.org/3.5/library/development.html
# https://docs.python.org/3.5/library/typing.html
# https://docs.python.org/3.5/library/pydoc.html
# https://docs.python.org/3.5/library/doctest.html
# https://docs.python.org/3.5/library/unittest.html
# https://docs.python.org/3.5/library/unittest.mock.html
# https://docs.python.org/3.5/library/unittest.mock-examples.html
# https://docs.python.org/3.5/library/2to3.html
# https://docs.python.org/3.5/library/test.html
# https://docs.python.org/3.5/library/test.html#module-test.support
# https://docs.python.org/3.5/library/debug.html
# https://docs.python.org/3.5/library/bdb.html
# https://docs.python.org/3.5/library/faulthandler.html
# https://docs.python.org/3.5/library/pdb.html
# https://docs.python.org/3.5/library/profile.html
# https://docs.python.org/3.5/library/timeit.html
# https://docs.python.org/3.5/library/trace.html
# https://docs.python.org/3.5/library/tracemalloc.html
# https://docs.python.org/3.5/library/distribution.html
# https://docs.python.org/3.5/library/distutils.html
# https://docs.python.org/3.5/library/ensurepip.html
# https://docs.python.org/3.5/library/venv.html
# https://docs.python.org/3.5/library/zipapp.html
# https://docs.python.org/3.5/library/python.html
# https://docs.python.org/3.5/library/sys.html
# https://docs.python.org/3.5/library/sysconfig.html
# https://docs.python.org/3.5/library/builtins.html
# https://docs.python.org/3.5/library/__main__.html
# https://docs.python.org/3.5/library/warnings.html
# https://docs.python.org/3.5/library/contextlib.html
# https://docs.python.org/3.5/library/abc.html
# https://docs.python.org/3.5/library/atexit.html
# https://docs.python.org/3.5/library/traceback.html
# https://docs.python.org/3.5/library/__future__.html
# https://docs.python.org/3.5/library/gc.html
# https://docs.python.org/3.5/library/inspect.html
# https://docs.python.org/3.5/library/site.html
# https://docs.python.org/3.5/library/fpectl.html
# https://docs.python.org/3.5/library/custominterp.html
# https://docs.python.org/3.5/library/code.html
# https://docs.python.org/3.5/library/codeop.html
# https://docs.python.org/3.5/library/modules.html
# https://docs.python.org/3.5/library/zipimport.html
# https://docs.python.org/3.5/library/pkgutil.html
# https://docs.python.org/3.5/library/modulefinder.html
# https://docs.python.org/3.5/library/runpy.html
# https://docs.python.org/3.5/library/importlib.html
# https://docs.python.org/3.5/library/language.html
# https://docs.python.org/3.5/library/parser.html
# https://docs.python.org/3.5/library/ast.html
# https://docs.python.org/3.5/library/symtable.html
# https://docs.python.org/3.5/library/symbol.html
# https://docs.python.org/3.5/library/token.html
# https://docs.python.org/3.5/library/keyword.html
# https://docs.python.org/3.5/library/tokenize.html
# https://docs.python.org/3.5/library/tabnanny.html
# https://docs.python.org/3.5/library/pyclbr.html
# https://docs.python.org/3.5/library/py_compile.html
# https://docs.python.org/3.5/library/compileall.html
# https://docs.python.org/3.5/library/dis.html
# https://docs.python.org/3.5/library/pickletools.html
# https://docs.python.org/3.5/library/misc.html
# https://docs.python.org/3.5/library/formatter.html
# https://docs.python.org/3.5/library/windows.html
# https://docs.python.org/3.5/library/msilib.html
# https://docs.python.org/3.5/library/msvcrt.html
# https://docs.python.org/3.5/library/winreg.html
# https://docs.python.org/3.5/library/winsound.html
# https://docs.python.org/3.5/library/unix.html
# https://docs.python.org/3.5/library/posix.html
# https://docs.python.org/3.5/library/pwd.html
# https://docs.python.org/3.5/library/spwd.html
# https://docs.python.org/3.5/library/grp.html
# https://docs.python.org/3.5/library/crypt.html
# https://docs.python.org/3.5/library/termios.html
# https://docs.python.org/3.5/library/tty.html
# https://docs.python.org/3.5/library/pty.html
# https://docs.python.org/3.5/library/fcntl.html
# https://docs.python.org/3.5/library/pipes.html
# https://docs.python.org/3.5/library/resource.html
# https://docs.python.org/3.5/library/nis.html
# https://docs.python.org/3.5/library/syslog.html
# https://docs.python.org/3.5/library/superseded.html
# https://docs.python.org/3.5/library/optparse.html
# https://docs.python.org/3.5/library/imp.html
# https://docs.python.org/3.5/library/undoc.html
# https://docs.python.org/3.5/library/undoc.html#platform-specific-modules
# https://docs.python.org/3.5/reference/grammar.html
# https://docs.python.org/3.5/library/intro.html
# https://docs.python.org/3.5/bugs.html
# https://github.com/python/cpython/blob/3.5/Doc/library/index.rst
# https://docs.python.org/3.5/genindex.html
# https://docs.python.org/3.5/py-modindex.html
# https://docs.python.org/3.5/library/intro.html
# https://docs.python.org/3.5/reference/grammar.html
# https://www.python.org/
# https://docs.python.org/3.5/index.html
# https://docs.python.org/3.5/copyright.html
# https://www.python.org/psf/donations/
# https://docs.python.org/3.5/bugs.html
# http://sphinx.pocoo.org/
