# %%
import requests 
from bs4 import BeautifulSoup
from urllib.parse import urlencode

# %%
import pandas as pd
import numpy as np

# %%
## 위도 경도 추출
def get_addr_info(keyword=""):
    url = "https://apis.zigbang.com/search/all?q={}&type=oneroom".format(keyword)
    response = requests.get(url)
    json_obj = response.json()
    return json_obj["items"][0]["lat"], json_obj["items"][0]["lng"]
    
# test code    
lat, lng = get_addr_info("성수동")
lat, lng
# Out:
# (37.541725158691406, 127.04335021972656)

# %%
def get_ids(lat, lng):
    
    url = "https://api.zigbang.com/v3/items2?\
lat_south={}&lat_north={}&lng_west={}&lng_east={}\
&room=[01,02,03,04,05]".format(lat - 0.01, lat + 0.01, lng - 0.01, lng + 0.01)
    
    params = {
        "lat_south": lat - 0.01,
        "lat_north": lat + 0.01,
        "lng_west": lng - 0.01,
        "lng_east": lng + 0.01,
        "room": "[01,02,03,04,05]",
    }
    params_str = urlencode(params)
    url = "https://api.zigbang.com/v3/items2?" + params_str
    response = requests.get(url)
    json_obj = response.json()
    items = json_obj["list_items"]
    return [item["simple_item"]["item_id"] for item in items]

# test code
ids = get_ids(lat, lng)
len(ids), ids[:5]
# Out:
# (78, [16981415, 17108377, 17161781, 17004354, 17073053])

# %%
from pandas.io.json import json_normalize
def get_items(ids):
    url = "https://api.zigbang.com/v3/items?detail=true&item_ids={}"\
.format(str(ids).replace(" ",""))
    response = requests.get(url)
    json_obj = response.json()
    items = json_obj["items"]
    datas = [item["item"] for item in items]
    result_df = json_normalize(datas)
    filter_colums = ["_floor", "address1", "address2", 
                     "user_email", "rent", "size", "deposit", "options"]
    return result_df[filter_colums]
    
# test code    
result_df = get_items(ids)    
result_df.iloc[:9]
# Out:
#   _floor       address1  address2             user_email  rent  size  deposit  \
# 0     3층  서울시 성동구 성수동1가    13-376   ssyssy4553@naver.com    70  11.0     3000
# 1     2층  서울시 성동구 성수동1가   656-829     soek0369@naver.com    75   9.0     2000
# 2     2층  서울시 성동구 성수동1가   685-414   powerhuman@naver.com    70   7.0     1000
# 3     4층  서울시 성동구 성수동1가   656-275    sdj2490@hanmail.net    79  10.0     2000
# 4     5층  서울시 성동구 성수동1가  656-1041  appedix81@hanmail.net    65   6.0     1000
# 5     2층  서울시 성동구 성수동1가   656-972     phsoon23@naver.com    45   5.0     1000
# 6    반지하  서울시 성동구 성수동2가    333-80      kbs_0616@daum.net    50   8.0      500
# 7    반지하  서울시 성동구 성수동1가   685-591    70ktcho@hanmail.net     0   8.0     5000
# 8     3층  서울시 성동구 성수동1가   656-342     sang2205@naver.com    50   8.0     1000
#
#                             options
# 0      에어컨,냉장고,세탁기,가스레인지,옷장,신발장,싱크대
# 1           에어컨,냉장고,세탁기,인덕션,신발장,싱크대
# 2  에어컨,냉장고,세탁기,인덕션,전자레인지,옷장,신발장,싱크대
# 3         에어컨,냉장고,세탁기,가스레인지,신발장,싱크대
# 4           에어컨,냉장고,세탁기,인덕션,신발장,싱크대
# 5   에어컨,냉장고,세탁기,가스레인지,책상,옷장,신발장,싱크대
# 6                   에어컨,세탁기,인덕션,싱크대
# 7                                 -
# 8        에어컨,냉장고,세탁기,인덕션,옷장,신발장,싱크대

# %%
def main(addr=""):
    lat, lng = get_addr_info(addr)
    ids = get_ids(lat, lng)
#     print(len(ids))
    return get_items(ids)

# %%
# test code
aa = main('부평구') 
aa
# Out:
#      _floor     address1 address2               user_email  rent  size  \
# 0        3층  인천시 부평구 부평동      909     ykpjjang@hanmail.net    48   6.0
# 1        3층  인천시 부평구 부평동    894-1     ykpjjang@hanmail.net    75  12.0
# 2        3층  인천시 부평구 부평동   464-32         sahera@naver.com    33   6.0
# 3        4층  인천시 부평구 부평동      909     ykpjjang@hanmail.net    55   7.0
# 4        2층  인천시 부평구 부평동   374-18        qorhks3@naver.com    40   8.0
# 5        4층  인천시 부평구 부평동   431-30         sahera@naver.com    48   7.0
# 6        3층  인천시 부평구 부평동      909     ykpjjang@hanmail.net    47   7.0
# 7        3층  인천시 부평구 부평동   372-57         sahera@naver.com    33   7.0
# 8       13층  인천시 부평구 부평동   397-33     sjdong90@hanmail.net    40   6.0
# 9        6층  인천시 부평구 부평동  529-162       oopunkoo@naver.com     0   5.0
# 10       6층  인천시 부평구 부평동   464-32         sahera@naver.com    33   6.0
# 11       5층  인천시 부평구 부평동   250-12         jjyjsb@naver.com    33  10.0
# 12       4층  인천시 부평구 산곡동   411-31      skgns4427@naver.com    43   7.0
# 13       1층  인천시 부평구 부평동   887-12        ytsrm@hanmail.net    26   7.0
# 14       4층  인천시 부평구 부평동   431-30   oneroomqueen@naver.com    48   7.5
# 15       3층  인천시 부평구 부평동   409-21     ykpjjang@hanmail.net    45   7.0
# 16       4층  인천시 부평구 부개동    478-1     ykpjjang@hanmail.net    45  12.0
# 17      반지하  인천시 부평구 부평동    899-9        koo2023@naver.com    34   6.0
# 18       4층  인천시 부평구 부평동   431-30        ahrami_@naver.com    48   7.5
# 19       4층  인천시 부평구 부평동    132-4         jjyjsb@naver.com    43  11.0
# 20       4층  인천시 부평구 부평동      909     ykpjjang@hanmail.net    55   9.0
# 21       2층  인천시 부평구 부평동   10-583      smsh10054@naver.com    35   7.0
# 22       4층  인천시 부평구 부평동   374-18       oopunkoo@naver.com    20   8.0
# 23       3층  인천시 부평구 산곡동   411-28     ykpjjang@hanmail.net    35   8.0
# 24       1층  인천시 부평구 부평동   10-485     ykpjjang@hanmail.net    42   7.0
# 25       4층  인천시 부평구 부평동    377-2        qorhks3@naver.com    37   7.0
# 26       2층  인천시 부평구 부평동   10-338     ykpjjang@hanmail.net    39   7.5
# 27      11층  인천시 부평구 부평동   436-14       hanjina8@naver.com     0  21.2
# 28       4층  인천시 부평구 부평동   431-30        qorhks3@naver.com    48   7.0
# 29       2층  인천시 부평구 부평동   12-167     ykpjjang@hanmail.net    40   7.0
# ..      ...          ...      ...                      ...   ...   ...
# 452      5층  인천시 부평구 부평동  433-127        ekwen68@naver.com    80  18.0
# 453     13층  인천시 부평구 부평동   372-12     hanulhouse@naver.com     0  17.0
# 454      5층  인천시 부평구 갈산동    176-8         sh11119@nate.com     0  16.0
# 455  고층/33층  인천시 부평구 부평동      954      rokmc1056@naver.com    45   6.7
# 456      3층  인천시 부평구 부평동   375-90     jangmi9353@naver.com     0  16.0
# 457  고층/33층  인천시 부평구 부평동      954    saint7600@hanmail.net    45   6.7
# 458      6층  인천시 부평구 부평동   464-51           zxc3@naver.com    65  17.0
# 459  고층/33층  인천시 부평구 부평동      954      rokmc1056@naver.com     0  14.1
# 460  고층/18층  인천시 부평구 부평동     54-3  happybank01@hanmail.net    45  11.0
# 461      5층  인천시 부평구 부평동   379-92          knn81@naver.com     0  20.0
# 462      5층  인천시 부평구 갈산동   178-35         sh11119@nate.com     0  16.9
# 463  고층/33층  인천시 부평구 부평동      954          knn81@naver.com    55  10.0
# 464   중층/9층  인천시 부평구 부평동  379-104          knn81@naver.com     0  16.0
# 465  고층/33층  인천시 부평구 부평동      954   myungmun0206@naver.com    65  14.0
# 466  저층/33층  인천시 부평구 부평동      954      rokmc1056@naver.com   100  14.1
# 467      4층  인천시 부평구 부평동    407-9     jangmi9353@naver.com    60  15.0
# 468  고층/15층  인천시 부평구 부평동   451-30        ekwen68@naver.com    70  14.0
# 469  저층/15층  인천시 부평구 부평동   439-12      kkk7433@hanmail.net    42   9.8
# 470      4층  인천시 부평구 부평동  433-172        psa7762@naver.com    30  10.0
# 471      5층  인천시 부평구 갈산동   178-35         sh11119@nate.com    40  16.9
# 472      3층  인천시 부평구 부평동   798-33  happybank01@hanmail.net     0  15.4
# 473  고층/33층  인천시 부평구 부평동      954      jswoo11@hanmail.net    60   9.8
# 474      3층  인천시 부평구 부평동     45-4           zxc3@naver.com     0  25.0
# 475  고층/20층  인천시 부평구 부평동   431-12    saint7600@hanmail.net    48   9.1
# 476      3층  인천시 부평구 부평동   119-42     sebalsebal@naver.com     0  18.0
# 477  고층/15층  인천시 부평구 부평동   431-15        4261237@naver.com    40   7.0
# 478      3층  인천시 부평구 부평동      881        ytsrm@hanmail.net    60  30.0
# 479      4층  인천시 부평구 부평동    407-9         sh11119@nate.com    60  18.0
# 480  저층/18층  인천시 부평구 부평동     54-3      psewoon@hanmail.net    40   8.8
# 481  고층/33층  인천시 부평구 부평동      954      jswoo11@hanmail.net    70  15.0
#
#      deposit                                 options
# 0        100              에어컨,냉장고,세탁기,인덕션,옷장,신발장,싱크대
# 1        100              에어컨,냉장고,세탁기,인덕션,옷장,신발장,싱크대
# 2         50        에어컨,냉장고,세탁기,인덕션,책상,책장,옷장,신발장,싱크대
# 3        100           에어컨,냉장고,세탁기,인덕션,책상,옷장,신발장,싱크대
# 4        500     에어컨,냉장고,세탁기,인덕션,전자레인지,책상,옷장,신발장,싱크대
# 5         60           에어컨,냉장고,세탁기,인덕션,책상,옷장,신발장,싱크대
# 6        100           에어컨,냉장고,세탁기,인덕션,책상,옷장,신발장,싱크대
# 7         50              에어컨,냉장고,세탁기,인덕션,옷장,신발장,싱크대
# 8        300              에어컨,냉장고,세탁기,인덕션,옷장,신발장,싱크대
# 9       3000        에어컨,냉장고,세탁기,인덕션,책상,책장,옷장,신발장,싱크대
# 10        50            에어컨,냉장고,세탁기,책상,책장,옷장,신발장,싱크대
# 11        50                 에어컨,냉장고,세탁기,인덕션,신발장,싱크대
# 12        60                 에어컨,냉장고,세탁기,인덕션,신발장,싱크대
# 13       300                                     싱크대
# 14        60     에어컨,냉장고,세탁기,인덕션,전자레인지,책상,옷장,신발장,싱크대
# 15       100                  에어컨,냉장고,세탁기,옷장,신발장,싱크대
# 16      1000                 에어컨,냉장고,세탁기,인덕션,신발장,싱크대
# 17        40                     에어컨,냉장고,세탁기,인덕션,싱크대
# 18        60           에어컨,냉장고,세탁기,인덕션,책상,옷장,신발장,싱크대
# 19       100      에어컨,냉장고,세탁기,가스레인지,전자레인지,옷장,신발장,싱크대
# 20       500           에어컨,냉장고,세탁기,인덕션,책상,옷장,신발장,싱크대
# 21       300              에어컨,냉장고,세탁기,인덕션,옷장,신발장,싱크대
# 22      2500  에어컨,냉장고,세탁기,인덕션,전자레인지,책상,책장,옷장,신발장,싱크대
# 23       100            에어컨,냉장고,세탁기,가스레인지,옷장,신발장,싱크대
# 24        50              에어컨,냉장고,세탁기,인덕션,옷장,신발장,싱크대
# 25       300           에어컨,냉장고,세탁기,가스레인지,인덕션,신발장,싱크대
# 26       100              에어컨,냉장고,세탁기,인덕션,침대,신발장,싱크대
# 27      8000                     에어컨,세탁기,인덕션,신발장,싱크대
# 28        60           에어컨,냉장고,세탁기,인덕션,책상,옷장,신발장,싱크대
# 29       300                 에어컨,냉장고,세탁기,인덕션,신발장,싱크대
# ..       ...                                     ...
# 452     1000                                       -
# 453    15300                                       -
# 454     8000                                       -
# 455      500            에어컨,냉장고,세탁기,가스레인지,옷장,신발장,싱크대
# 456    15000                                       -
# 457      500            에어컨,냉장고,세탁기,가스레인지,옷장,신발장,싱크대
# 458     1000                                       -
# 459    20000            에어컨,냉장고,세탁기,가스레인지,옷장,신발장,싱크대
# 460      500            에어컨,냉장고,세탁기,가스레인지,옷장,신발장,싱크대
# 461    15500                                       -
# 462    10000                                       -
# 463      300            에어컨,냉장고,세탁기,가스레인지,옷장,신발장,싱크대
# 464    15500                           가스레인지,신발장,싱크대
# 465     2000            에어컨,냉장고,세탁기,가스레인지,옷장,신발장,싱크대
# 466     2000         에어컨,냉장고,세탁기,가스레인지,침대,옷장,신발장,싱크대
# 467     3000                                       -
# 468     1000                           가스레인지,신발장,싱크대
# 469     1000            에어컨,냉장고,세탁기,가스레인지,옷장,신발장,싱크대
# 470     1000                                       -
# 471     2000                                       -
# 472    12000                                       -
# 473      500            에어컨,냉장고,세탁기,가스레인지,옷장,신발장,싱크대
# 474    24000                                       -
# 475      500              에어컨,냉장고,세탁기,인덕션,옷장,신발장,싱크대
# 476    15000                                       -
# 477      500              에어컨,냉장고,세탁기,인덕션,옷장,신발장,싱크대
# 478     2000                                       -
# 479     3000                                       -
# 480      500         에어컨,냉장고,세탁기,가스레인지,침대,옷장,신발장,싱크대
# 481     1000            에어컨,냉장고,세탁기,가스레인지,옷장,신발장,싱크대
#
# [482 rows x 8 columns]

# %%
## json 구조 접근법
json_data # 중첩 json 구조로 되어있음. 'name','version','url','data' 의 key값들 중 'data'에 접근해야함

# json_data['data'] # list의 안의 json 구조로 되어있음. 따라서 우선 리스트로 접근하기

# json_data['data'][0] # 다시 json구조 , 다시 key값으로 해야함

# json_data['data'][0]['서울특별시'] # 결국 서울특별시에 해당하는 구들이 list형태로 생김

# res = [] # 구 list를 담기위한 list
# res.append(json_data['data'][0]['서울특별시']) # res에 리스트 append
# res.append(json_data['data'][1]['부산광역시'])
# res.append(json_data['data'][2]['인천광역시'])

# sum_res = sum(res,[]) #리스트안의 리스트들 구조로되어있기 때문에 접근을 더 쉽게 하기위해 list를 일원화 시킴 [[]] => []
# Out:
# {'name': 'korea-administrative-district',
#  'version': '20160125',
#  'url': 'https://github.com/cosmosfarm/korea-administrative-district',
#  'data': [{'서울특별시': ['종로구',
#     '중구',
#     '용산구',
#     '성동구',
#     '광진구',
#     '동대문구',
#     '중랑구',
#     '성북구',
#     '강북구',
#     '도봉구',
#     '노원구',
#     '은평구',
#     '서대문구',
#     '마포구',
#     '양천구',
#     '강서구',
#     '구로구',
#     '금천구',
#     '영등포구',
#     '동작구',
#     '관악구',
#     '서초구',
#     '강남구',
#     '송파구',
#     '강동구']},
#   {'부산광역시': ['중구',
#     '서구',
#     '동구',
#     '영도구',
#     '부산진구',
#     '동래구',
#     '남구',
#     '북구',
#     '강서구',
#     '해운대구',
#     '사하구',
#     '금정구',
#     '연제구',
#     '수영구',
#     '사상구',
#     '기장군']},
#   {'인천광역시': ['중구',
#     '동구',
#     '남구',
#     '연수구',
#     '남동구',
#     '부평구',
#     '계양구',
#     '서구',
#     '강화군',
#     '옹진군']},
#   {'대구광역시': ['중구', '동구', '서구', '남구', '북구', '수성구', '달서구', '달성군']},
#   {'광주광역시': ['동구', '서구', '남구', '북구', '광산구']},
#   {'대전광역시': ['동구', '중구', '서구', '유성구', '대덕구']},
#   {'울산광역시': ['중구', '남구', '동구', '북구', '울주군']},
#   {'세종특별자치시': []},
#   {'경기도': ['가평군',
#     '고양시',
#     '과천시',
#     '광명시',
#     '광주시',
#     '구리시',
#     '군포시',
#     '김포시',
#     '남양주시',
#     '동두천시',
#     '부천시',
#     '성남시',
#     '수원시',
#     '시흥시',
#     '안산시',
#     '안성시',
#     '안양시',
#     '양주시',
#     '양평군',
#     '여주시',
#     '연천군',
#     '오산시',
#     '용인시',
#     '의왕시',
#     '의정부시',
#     '이천시',
#     '파주시',
#     '평택시',
#     '포천시',
#     '하남시',
#     '화성시']},
#   {'강원도': ['원주시',
#     '춘천시',
#     '강릉시',
#     '동해시',
#     '속초시',
#     '삼척시',
#     '홍천군',
#     '태백시',
#     '철원군',
#     '횡성군',
#     '평창군',
#     '영월군',
#     '정선군',
#     '인제군',
#     '고성군',
#     '양양군',
#     '화천군',
#     '양구군']},
#   {'충청북도': ['청주시',
#     '충주시',
#     '제천시',
#     '보은군',
#     '옥천군',
#     '영동군',
#     '증평군',
#     '진천군',
#     '괴산군',
#     '음성군',
#     '단양군']},
#   {'충청남도': ['천안시',
#     '공주시',
#     '보령시',
#     '아산시',
#     '서산시',
#     '논산시',
#     '계룡시',
#     '당진시',
#     '금산군',
#     '부여군',
#     '서천군',
#     '청양군',
#     '홍성군',
#     '예산군',
#     '태안군']},
#   {'경상북도': ['포항시',
#     '경주시',
#     '김천시',
#     '안동시',
#     '구미시',
#     '영주시',
#     '영천시',
#     '상주시',
#     '문경시',
#     '경산시',
#     '군위군',
#     '의성군',
#     '청송군',
#     '영양군',
#     '영덕군',
#     '청도군',
#     '고령군',
#     '성주군',
#     '칠곡군',
#     '예천군',
#     '봉화군',
#     '울진군',
#     '울릉군']},
#   {'경상남도': ['창원시',
#     '김해시',
#     '진주시',
#     '양산시',
#     '거제시',
#     '통영시',
#     '사천시',
#     '밀양시',
#     '함안군',
#     '거창군',
#     '창녕군',
#     '고성군',
#     '하동군',
#     '합천군',
#     '남해군',
#     '함양군',
#     '산청군',
#     '의령군']},
#   {'전라북도': ['전주시',
#     '익산시',
#     '군산시',
#     '정읍시',
#     '완주군',
#     '김제시',
#     '남원시',
#     '고창군',
#     '부안군',
#     '임실군',
#     '순창군',
#     '진안군',
#     '장수군',
#     '무주군']},
#   {'전라남도': ['여수시',
#     '순천시',
#     '목포시',
#     '광양시',
#     '나주시',
#     '무안군',
#     '해남군',
#     '고흥군',
#     '화순군',
#     '영암군',
#     '영광군',
#     '완도군',
#     '담양군',
#     '장성군',
#     '보성군',
#     '신안군',
#     '장흥군',
#     '강진군',
#     '함평군',
#     '진도군',
#     '곡성군',
#     '구례군']},
#   {'제주특별자치도': ['제주시', '서귀포시']}]}

# %%
import json
## encoding utf-8
with open('korea-administrative-district.json', encoding='utf-8') as jsonfile: # korea-administrative-district.json 행정구역 json
    json_data = json.load(jsonfile)
## 시 추출    
parsing_list = []
for i in range(0,3):
    parsing_list.append(list(json_data['data'][i].keys())) 

parsing_data = []
# parsing_data.append(list(json_data['data'][0]['서울특별시']))
parsing_data.append(list(json_data['data'][1]['부산광역시']))
# parsing_data.append(list(json_data['data'][2]['인천광역시']))
    
## 구/군 추출
parsing_data = sum(parsing_data,[])

# %%
json_data
# Out:
# {'name': 'korea-administrative-district',
#  'version': '20160125',
#  'url': 'https://github.com/cosmosfarm/korea-administrative-district',
#  'data': [{'서울특별시': ['종로구',
#     '중구',
#     '용산구',
#     '성동구',
#     '광진구',
#     '동대문구',
#     '중랑구',
#     '성북구',
#     '강북구',
#     '도봉구',
#     '노원구',
#     '은평구',
#     '서대문구',
#     '마포구',
#     '양천구',
#     '강서구',
#     '구로구',
#     '금천구',
#     '영등포구',
#     '동작구',
#     '관악구',
#     '서초구',
#     '강남구',
#     '송파구',
#     '강동구']},
#   {'부산광역시': ['중구',
#     '서구',
#     '동구',
#     '영도구',
#     '부산진구',
#     '동래구',
#     '남구',
#     '북구',
#     '강서구',
#     '해운대구',
#     '사하구',
#     '금정구',
#     '연제구',
#     '수영구',
#     '사상구',
#     '기장군']},
#   {'인천광역시': ['중구',
#     '동구',
#     '남구',
#     '연수구',
#     '남동구',
#     '부평구',
#     '계양구',
#     '서구',
#     '강화군',
#     '옹진군']},
#   {'대구광역시': ['중구', '동구', '서구', '남구', '북구', '수성구', '달서구', '달성군']},
#   {'광주광역시': ['동구', '서구', '남구', '북구', '광산구']},
#   {'대전광역시': ['동구', '중구', '서구', '유성구', '대덕구']},
#   {'울산광역시': ['중구', '남구', '동구', '북구', '울주군']},
#   {'세종특별자치시': []},
#   {'경기도': ['가평군',
#     '고양시',
#     '과천시',
#     '광명시',
#     '광주시',
#     '구리시',
#     '군포시',
#     '김포시',
#     '남양주시',
#     '동두천시',
#     '부천시',
#     '성남시',
#     '수원시',
#     '시흥시',
#     '안산시',
#     '안성시',
#     '안양시',
#     '양주시',
#     '양평군',
#     '여주시',
#     '연천군',
#     '오산시',
#     '용인시',
#     '의왕시',
#     '의정부시',
#     '이천시',
#     '파주시',
#     '평택시',
#     '포천시',
#     '하남시',
#     '화성시']},
#   {'강원도': ['원주시',
#     '춘천시',
#     '강릉시',
#     '동해시',
#     '속초시',
#     '삼척시',
#     '홍천군',
#     '태백시',
#     '철원군',
#     '횡성군',
#     '평창군',
#     '영월군',
#     '정선군',
#     '인제군',
#     '고성군',
#     '양양군',
#     '화천군',
#     '양구군']},
#   {'충청북도': ['청주시',
#     '충주시',
#     '제천시',
#     '보은군',
#     '옥천군',
#     '영동군',
#     '증평군',
#     '진천군',
#     '괴산군',
#     '음성군',
#     '단양군']},
#   {'충청남도': ['천안시',
#     '공주시',
#     '보령시',
#     '아산시',
#     '서산시',
#     '논산시',
#     '계룡시',
#     '당진시',
#     '금산군',
#     '부여군',
#     '서천군',
#     '청양군',
#     '홍성군',
#     '예산군',
#     '태안군']},
#   {'경상북도': ['포항시',
#     '경주시',
#     '김천시',
#     '안동시',
#     '구미시',
#     '영주시',
#     '영천시',
#     '상주시',
#     '문경시',
#     '경산시',
#     '군위군',
#     '의성군',
#     '청송군',
#     '영양군',
#     '영덕군',
#     '청도군',
#     '고령군',
#     '성주군',
#     '칠곡군',
#     '예천군',
#     '봉화군',
#     '울진군',
#     '울릉군']},
#   {'경상남도': ['창원시',
#     '김해시',
#     '진주시',
#     '양산시',
#     '거제시',
#     '통영시',
#     '사천시',
#     '밀양시',
#     '함안군',
#     '거창군',
#     '창녕군',
#     '고성군',
#     '하동군',
#     '합천군',
#     '남해군',
#     '함양군',
#     '산청군',
#     '의령군']},
#   {'전라북도': ['전주시',
#     '익산시',
#     '군산시',
#     '정읍시',
#     '완주군',
#     '김제시',
#     '남원시',
#     '고창군',
#     '부안군',
#     '임실군',
#     '순창군',
#     '진안군',
#     '장수군',
#     '무주군']},
#   {'전라남도': ['여수시',
#     '순천시',
#     '목포시',
#     '광양시',
#     '나주시',
#     '무안군',
#     '해남군',
#     '고흥군',
#     '화순군',
#     '영암군',
#     '영광군',
#     '완도군',
#     '담양군',
#     '장성군',
#     '보성군',
#     '신안군',
#     '장흥군',
#     '강진군',
#     '함평군',
#     '진도군',
#     '곡성군',
#     '구례군']},
#   {'제주특별자치도': ['제주시', '서귀포시']}]}

# %%
import cx_Oracle # 파이썬 oracle 연동 모듈 

con = cx_Oracle.connect("KIHYUK/3927@192.168.0.216:1521/orcl") # 연결 설정

for data in parsing_data:
    
    df = main(data)
    rows = list(df.itertuples(index=False,name=None))
    cursor = con.cursor()
    cursor.executemany("INSERT INTO HOUSE_TE(FLOOR,ADDRESS1,ADDRESS2,USER_EMAIL,RENT,SIZES,DEPOSIT,OPTIONS) VALUES(:1,:2,:3,:4,:5,:6,:7,:8)",rows)
    con.commit()

con.close()
