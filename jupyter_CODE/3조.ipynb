# %%
import pandas as pd
import numpy as np

# %%
df2 = pd.read_csv('C:/Users/Playdata/Documents/GitHub/Jupyter_Repo/Data/funda_train.csv')

# %%
df2
# Out:
#          store_id  card_id card_company transacted_date transacted_time  \
# 0               0        0            b      2016-06-01           13:13
# 1               0        1            h      2016-06-01           18:12
# 2               0        2            c      2016-06-01           18:52
# 3               0        3            a      2016-06-01           20:22
# 4               0        4            c      2016-06-02           11:06
# 5               0        5            c      2016-06-02           13:09
# 6               0        6            f      2016-06-02           15:33
# 7               0        7            a      2016-06-02           17:18
# 8               0        8            c      2016-06-02           18:30
# 9               0        9            a      2016-06-02           19:56
# 10              0       10            f      2016-06-02           22:26
# 11              0       11            c      2016-06-03           12:43
# ...

# %% [markdown]
# > 전체 지역 파악 (중복제거)

# %%
df2['region'].nunique()
# Out:
# 180

# %% [markdown]
# > store_id 파악 (중복제거)

# %%
df2['store_id'].nunique()
# Out:
# 1967

# %% [markdown]
# > 지역별 매출 평균액 비교

# %%
df2.groupby(df2.region)['amount'].mean().sort_values(ascending=False)
# Out:
# region
# 경기 과천시     58984.756834
# 전남 완도군     45119.572058
# 서울 광진구     44420.386452
# 경북 상주시     38071.436932
# 서울 강남구     33144.933447
# 경기 김포시     27419.659890
# 전남 담양군     26967.862115
# 부산 기장군     24468.758484
# 충북 옥천군     23071.366091
# 경기 용인시     22128.524789
# 세종 달빛로     21255.624427
# 경남 함안군     21203.709730
# 서울 강서구     20584.460027
# 인천 서구      20388.075953
# 부산 남구      19885.195926
# 부산 연제구     19779.905681
# 서울 관악구     19390.962943
# 서울 서초구     18880.932488
# 서울 금천구     18243.991813
# 부산 해운대구    18230.545938
# 서울 영등포구    18083.669150
# 전남 나주시     18017.438556
# 광주 남구      17990.045479
# 강원 태백시     17826.135535
# 경기 화성시     17651.248351
# 경기 성남시     17299.404527
# 경북 경주시     17138.902825
# 인천 동구      17055.231582
# 강원 속초시     16593.699141
# 전남 고흥군     15912.866868
#                ...
# 경기 양평군      5438.462804
# 서울 서대문구     5422.085845
# 경북 성주군      5408.653610
# 경북 영주시      5328.093172
# 충북 증평군      5261.246131
# 부산 강서구      5170.683741
# 서울 은평구      5134.065535
# ...

# %%
df2.groupby(df2.region).size().sort_values(ascending=False)
# Out:
# region
# 경기 수원시     122029
# 충북 청주시     116766
# 경남 창원시     107147
# 경남 김해시     100673
# 경기 평택시      82138
# 서울 마포구      78652
# 제주 제주시      68130
# 경북 포항시      67490
# 서울 강남구      65312
# 경북 구미시      65235
# 대전 서구       63564
# 충남 천안시      62038
# 전북 전주시      61720
# 서울 송파구      61290
# 대구 수성구      57165
# 경기 성남시      56301
# 경기 부천시      55918
# 경남 양산시      53871
# 경북 경주시      52843
# 경기 화성시      51850
# 경기 파주시      50794
# 경기 용인시      50530
# 서울 서초구      50512
# 경기 광주시      49975
# 울산 남구       47674
# 인천 남동구      47417
# 경기 의정부시     47333
# 제주 서귀포시     46541
# 강원 원주시      46282
# 충북 충주시      45641
#             ...
# 충북 단양군       4556
# 충남 부여군       4442
# 경기 양평군       4340
# 경남 창녕군       4183
# 충남 홍성군       3816
# 강원 홍천군       3664
# 전북 순창군       3519
# 전남 담양군       3448
# 충북 옥천군       3201
# 경기 과천시       3193
# 경북 울진군       3129
# 전남 함평군       3092
# 강원 양구군       2848
# 전북 남원시       2815
# 경기 의왕시       2801
# 충남 예산군       2654
# 전남 고흥군       2600
# 경북 상주시       2563
# ...

# %%
df2['type_of_business'] = df2['type_of_business'].astype('category')

# %%
pivot_data = pd.pivot_table(df2,index='region',values='amount', aggfunc=np.sum)

# %%
## pivot_data

pivot_data.sort_values(by=['amount'],ascending=False)
# Out:
#                amount
# region
# 서울 강남구   2.164762e+09
# 서울 광진구   1.905546e+09
# 경기 수원시   1.382518e+09
# 경기 용인시   1.118154e+09
# 서울 마포구   1.071436e+09
# 경기 성남시   9.739738e+08
# 서울 서초구   9.537137e+08
# 충북 청주시   9.396727e+08
# 경기 화성시   9.152172e+08
# 경북 경주시   9.056710e+08
# 경남 창원시   9.046384e+08
# 부산 해운대구  8.308571e+08
# 경남 김해시   8.177454e+08
# 서울 송파구   7.953902e+08
# 대전 서구    7.781977e+08
# 인천 서구    7.558268e+08
# 전북 전주시   6.844674e+08
# 경기 평택시   6.263310e+08
# 경기 부천시   6.204626e+08
# 부산 기장군   6.123796e+08
# 제주 제주시   6.084415e+08
# 경북 구미시   5.825456e+08
# 대구 달서구   5.807082e+08
# 경북 포항시   5.724012e+08
# 울산 남구    5.691678e+08
# 서울 영등포구  5.417325e+08
# 경기 고양시   5.297558e+08
# 충남 천안시   5.274084e+08
# 광주 서구    4.992560e+08
# 강원 춘천시   4.953614e+08
# ...               ...
# 인천 동구    3.803317e+07
# 경남 창녕군   3.742409e+07
# 충북 진천군   3.545923e+07
# 경남 남해군   3.188938e+07
# 경북 성주군   3.140264e+07
# 대구 서구    3.123064e+07
# 경기 의왕시   3.100029e+07
# 강원 양구군   3.075680e+07
# 전남 완도군   3.072643e+07
# ...

# %%
pivot_data = pd.pivot_table(df2,index='region',values='amount', aggfunc=np.mean)
pivot_data.sort_values(by=['amount'],ascending=False)
# Out:
#                amount
# region
# 경기 과천시   58984.756834
# 전남 완도군   45119.572058
# 서울 광진구   44420.386452
# 경북 상주시   38071.436932
# 서울 강남구   33144.933447
# 경기 김포시   27419.659890
# 전남 담양군   26967.862115
# 부산 기장군   24468.758484
# 충북 옥천군   23071.366091
# 경기 용인시   22128.524789
# 세종 달빛로   21255.624427
# 경남 함안군   21203.709730
# 서울 강서구   20584.460027
# 인천 서구    20388.075953
# 부산 남구    19885.195926
# 부산 연제구   19779.905681
# 서울 관악구   19390.962943
# 서울 서초구   18880.932488
# 서울 금천구   18243.991813
# 부산 해운대구  18230.545938
# 서울 영등포구  18083.669150
# 전남 나주시   18017.438556
# 광주 남구    17990.045479
# 강원 태백시   17826.135535
# 경기 화성시   17651.248351
# 경기 성남시   17299.404527
# 경북 경주시   17138.902825
# 인천 동구    17055.231582
# 강원 속초시   16593.699141
# 전남 고흥군   15912.866868
# ...               ...
# 경기 양평군    5438.462804
# 서울 서대문구   5422.085845
# 경북 성주군    5408.653610
# 경북 영주시    5328.093172
# 충북 증평군    5261.246131
# 부산 강서구    5170.683741
# 서울 은평구    5134.065535
# 충남 부여군    4806.961793
# 경기 안성시    4787.986138
# ...
