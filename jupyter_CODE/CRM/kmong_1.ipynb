# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/KIHyuk/Documents/GitHub/Jupyter_Repo/jupyter_CODE/CRM/data/credit_card_data.csv')

# %%
df
# Out:
#      pop_cd  year  month  avg_score  avg_rat city  sex ages  population  \
# 0      L011  2016      1        812        2   서울  NaN  10대       55000
# 1      L011  2016      2        773        4   서울  NaN  10대      380000
# 2      L011  2016      3        771        4   서울  NaN  10대      387000
# 3      L011  2016      4        770        4   서울  NaN  10대      412000
# 4      L011  2016      5        771        4   서울  NaN  10대      414000
# ...     ...   ...    ...        ...      ...  ...  ...  ...         ...
# 3883    Y95  2017      8        819        3  NaN   여자  90대      232000
# 3884    Y95  2017      9        819        3  NaN   여자  90대      235000
# 3885    Y95  2017     10        819        3  NaN   여자  90대      239000
# 3886    Y95  2017     11        819        3  NaN   여자  90대      243000
# 3887    Y95  2017     12        820        3  NaN   여자  90대      265000
#
#       num_opencard  ...  monthly_installments_loan  monthly_insurance_loan  \
# ...

# %%
df_cate = pd.read_csv('./data/kmong-category.csv')

# %%
df_cate
# Out:
#      depth  categoryid categoryname  cat1_id  cat2_id  cat3_id      cat1  \
# 0        1           1          디자인        1      NaN      NaN       디자인
# 1        1           2          마케팅        2      NaN      NaN       마케팅
# 2        1           3        번역·통역        3      NaN      NaN     번역·통역
# 3        1           4         문서작성        4      NaN      NaN      문서작성
# 4        1           6     IT·프로그래밍        6      NaN      NaN  IT·프로그래밍
# ..     ...         ...          ...      ...      ...      ...       ...
# 240      3       72501           모델        7    725.0  72501.0    콘텐츠 제작
# 241      3       72502           MC        7    725.0  72502.0    콘텐츠 제작
# 242      3       72503           배우        7    725.0  72503.0    콘텐츠 제작
# 243      3       72504           공연        7    725.0  72504.0    콘텐츠 제작
# 244      3       72505           기타        7    725.0  72505.0    콘텐츠 제작
#
#       cat2 cat3
# 0      NaN  NaN
# 1      NaN  NaN
# 2      NaN  NaN
# 3      NaN  NaN
# ...

# %%
df_conv = pd.read_csv('./data/kmong-conversion.csv')

# %%
df_conv
# Out:
#        eventcategory isfirstactivity   apppackagename appversion devicetype  \
# 0               goal           False    com.kmong.iOS      4.0.4     iPhone
# 1               goal           False  com.kmong.kmong      3.3.5   SM-N935S
# 2               goal           False    com.kmong.iOS      4.0.4     iPhone
# 3         foreground             NaN    com.kmong.iOS      4.0.4     iPhone
# 4               goal           False    com.kmong.iOS      4.0.4     iPhone
# ...              ...             ...              ...        ...        ...
# 434239          goal           False  com.kmong.kmong      3.3.5   SM-G930L
# 434240          goal           False  com.kmong.kmong      3.3.5   SM-N950N
# 434241          goal           False  com.kmong.kmong      3.3.5   SM-G930L
# 434242          exit             NaN  com.kmong.kmong      3.3.5   SM-N950N
# 434243          goal           False  com.kmong.kmong      3.3.5   SM-G965N
#
# ...

# %%
df_fun  = pd.read_csv('./data/kmong-funnel.csv')

# %%
df_fun
# Out:
#      Lv2                           viewid                 viewid desc  Lv1  \
# 0   1100                             home                       홈 (탭)   11
# 1   1210                    category_list                 카테고리 목록 (탭)   12
# 2   1200                     category_gig                   카테고리-상품목록   12
# 3   1300                           search                          검색   13
# 4   1301                       search_gig                     검색-상품목록   13
# 5   1302                    search_seller                      검색-전문가   13
# 6   1400                       gig_detail                        상품상세   14
# 7   1401                gig_detail_option                   상품상세-상품선택   14
# 8   1420                          profile                      전문가프로필   14
# 9   1520                        login_sns                       간편로그인   15
# 10  1500                      login_email                간편로그인-이메일로그인   15
# ...
