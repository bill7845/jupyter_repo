# %%
# pip install --upgrade google-cloud-bigquery

# %%
# pip install pydata_google_auth

# %%
# pip install pandas_gbq

# %%
from google.cloud import bigquery
from google.oauth2 import service_account

# load service_account key json file (in local)
# service_account 만들때 권한을 bigquery 매니저로하니깐 성공..
credentials = service_account.Credentials.from_service_account_file("practice-028a6b1e967a.json")

# gcp project
project_id = 'practice-281902'
client = bigquery.Client(credentials = credentials, project=project_id)

# query
query_job = client.query("""
SELECT * FROM data.airbnb_nyc
""")

df = query_job.to_dataframe()

# %%
df
# Out:
#            id                                               name  host_id  \
# 0      587740      Designer open space in TriBeCa Soho 1000sq ft  2899508
# 1       19159               Spacious luminous apt Upper West NYC    73051
# 2      144087                              LUXURY OF THE HORIZON   616825
# 3      224006                 Harlem/Manhattan Classic Apartment  1165231
# 4      460999                     Beautiful duplex apt in Harlem   128890
# ...       ...                                                ...      ...
# 2726   816888                          Whole Manhattan Apartment  2805766
# 2727   876355                      Large 1BR Columbia University  3994331
# 2728  1150869  Large UWS Apt $170.00/day May 2018- September ...  6142196
# 2729   400466  Bright Brooklyn Flat w/Park Views, 30 day minimum  1985759
# 2730  1423112                       Private Room in Brooklyn, NY  7659871
#
#            host_name neighbourhood_group              neighbourhood  \
# ...
