# %% [markdown]
# ## G-Market 크롤링
#
# * G-Market의 best item 정보를 크롤링 후 mysql에 저장할것.

# %% [markdown]
# 1. `DB 스키마 설계`

# %%
# # table - ranking
# CREATE TABLE ranking (
#     num INT AUTO_INCREMENT NOT NULL PRIMARY KEY, # 카테고리별로 랭킹 1,2,...존재함. ranking을 pk로 사용 불가
#     main_category VARCHAR(50) NOT NULL, # 
#     sub_category VARCHAR(50) NOT NULL, # 
#     item_ranking TINYINT UNSIGNED NOT NULL, # 상품 랭킹
#     item_code VARCHAR(20) NOT NULL, #
#     FOREIGN KEY(item_code) REFERENCES items(item_code) # 상품별 code를 참조함
# );

# # table - item
# CREATE TABLE items(
#     item_code VARCHAR(20) NOT NULL PRIMARY KEY,
#     title VARCHAR(200) NOT NULL,
#     ori_price INT NOT NULL,
#     dis_price INT NOT NULL,
#     discount_percent INT NOT NULL,
#     provider VARCHAR(100)
# );

# %%
import pymysql

db = pymysql.connect(host='localhost', port=3306, user='root', passwd='3927', db='bestproducts', charset='utf8')
cursor = db.cursor()

sql = '''
CREATE TABLE items(
    item_code VARCHAR(20) NOT NULL PRIMARY KEY,
    title VARCHAR(200) NOT NULL,
    ori_price INT NOT NULL,
    dis_price INT NOT NULL,
    discount_percent INT NOT NULL,
    provider VARCHAR(100)
);    
'''

cursor.execute(sql)

sql = '''
CREATE TABLE ranking (
    num INT AUTO_INCREMENT NOT NULL PRIMARY KEY, # 카테고리별로 랭킹 1,2,...존재함. ranking을 pk로 사용 불가
    main_category VARCHAR(50) NOT NULL, # 
    sub_category VARCHAR(50) NOT NULL, # 
    item_ranking TINYINT UNSIGNED NOT NULL, # 상품 랭킹
    item_code VARCHAR(20) NOT NULL, #
    FOREIGN KEY(item_code) REFERENCES items(item_code) # 상품별 code를 참조함
);
'''
cursor.execute(sql)

db.commit()
db.close()

# %% [markdown]
# 2. `크롤링`

# %%
import requests
from bs4 import BeautifulSoup

# %%
## main category 크롤링
res = requests.get('http://corners.gmarket.co.kr/Bestsellers') # base url
soup = BeautifulSoup(res.content, 'html.parser')

categories = soup.select('div.gbest-cate ul.by-group li a')

for category in categories:
    print("http://corners.gmarket.co.kr/" + category['href'], category.get_text())
# Out:
# http://corners.gmarket.co.kr//Bestsellers ALL
# http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G01 패션의류
# http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G02 신발/잡화
# http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G03 화장품/헤어
# http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G04 유아동/출산
# http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G07 식품
# http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G08 생활/주방/건강
# http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G09 가구/침구
# http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G05 스포츠/자동차
# http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G06 컴퓨터/전자
# http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G10 도서/음반
# http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G11 여행
# http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G12 e쿠폰/티켓

# %%
## sub category 크롤링

def get_category(category_link, category_name): # input main category link, main category name
    print("***Main Category*** : ",category_name) # 현재 어느 메인의 서브를 파싱중인지 알기위해
    
    res = requests.get(category_link)
    soup = BeautifulSoup(res.content, 'html.parser') # 해당 메인에서의 서브카테고리 파싱
    sub_categories = soup.select('div.navi.group ul li a')
    for sub_category in sub_categories:
        print("Sub Category :",sub_category.get_text(),"Sub Category Link :" ,"http://corners.gmarket.co.kr/" + sub_category['href'])
        print("###########################################################################")

for category in categories:
    get_category("http://corners.gmarket.co.kr/" + category['href'], category.get_text())
# Out:
# ***Main Category*** :  ALL
# ***Main Category*** :  패션의류
# Sub Category : 여성의류 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G01&subGroupCode=S102
# ###########################################################################
# Sub Category : 남성의류 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G01&subGroupCode=S002
# ###########################################################################
# Sub Category : 언더웨어 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G01&subGroupCode=S088
# ###########################################################################
# Sub Category : 브랜드 여성의류 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G01&subGroupCode=S161
# ###########################################################################
# Sub Category : 브랜드 남성의류 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G01&subGroupCode=S162
# ###########################################################################
# Sub Category : 브랜드 진/캐쥬얼  Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G01&subGroupCode=S163
# ###########################################################################
# ***Main Category*** :  신발/잡화
# Sub Category : 여성신발 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G02&subGroupCode=S004
# ###########################################################################
# Sub Category : 남성신발 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G02&subGroupCode=S005
# ###########################################################################
# Sub Category : 운동화 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G02&subGroupCode=S007
# ###########################################################################
# Sub Category : 가방/지갑 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G02&subGroupCode=S008
# ###########################################################################
# Sub Category : 여행가방 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G02&subGroupCode=S172
# ###########################################################################
# Sub Category : 잡화/액세서리 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G02&subGroupCode=S127
# ###########################################################################
# Sub Category : 수입명품 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G02&subGroupCode=S134
# ###########################################################################
# Sub Category : 브랜드 신발/가방 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G02&subGroupCode=S166
# ###########################################################################
# Sub Category : 브랜드 쥬얼리/시계 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G02&subGroupCode=S167
# ###########################################################################
# ***Main Category*** :  화장품/헤어
# Sub Category : 화장품 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G03&subGroupCode=S011
# ###########################################################################
# Sub Category : 보습제품 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G03&subGroupCode=S081
# ###########################################################################
# Sub Category : 남성화장품 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G03&subGroupCode=S055
# ###########################################################################
# Sub Category : 향수 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G03&subGroupCode=S012
# ###########################################################################
# Sub Category : 화장소품 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G03&subGroupCode=S016
# ###########################################################################
# Sub Category : 바디클렌져/바디로션 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G03&subGroupCode=S013
# ###########################################################################
# Sub Category : 샴푸/헤어에센스/스타일링 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G03&subGroupCode=S014
# ###########################################################################
# Sub Category : 제모/데오드란트/슬리밍 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G03&subGroupCode=S069
# ###########################################################################
# Sub Category : 백화점 명품화장품 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G03&subGroupCode=S171
# ###########################################################################
# ***Main Category*** :  유아동/출산
# Sub Category : 기저귀 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G04&subGroupCode=S017
# ###########################################################################
# Sub Category : 분유/이유식 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G04&subGroupCode=S063
# ###########################################################################
# Sub Category : 물티슈 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G04&subGroupCode=S020
# ###########################################################################
# Sub Category : 신생아의류/잡화 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G04&subGroupCode=S131
# ###########################################################################
# Sub Category : 유아동의류 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G04&subGroupCode=S064
# ###########################################################################
# Sub Category : 주니어의류 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G04&subGroupCode=S077
# ###########################################################################
# Sub Category : 아동화  Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G04&subGroupCode=S132
# ###########################################################################
# Sub Category : 아동가방/잡화  Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G04&subGroupCode=S133
# ###########################################################################
# Sub Category : 출산/유아용품 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G04&subGroupCode=S018
# ###########################################################################
# Sub Category : 장난감/교육완구 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G04&subGroupCode=S076
# ###########################################################################
# Sub Category : 임부복/용품 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G04&subGroupCode=S062
# ###########################################################################
# Sub Category : 생리대 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G04&subGroupCode=S019
# ###########################################################################
# Sub Category : 브랜드 아동패션 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G04&subGroupCode=S168
# ###########################################################################
# Sub Category : 홈플러스 베이비 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G04&subGroupCode=S158
# ###########################################################################
# Sub Category :  Sub Category Link : http://corners.gmarket.co.kr//bestseller/BestSellerList.asp?group_kind=G&group_cd=G10&groupSub_kind=GS&groupSub_cd=S073
# ###########################################################################
# ***Main Category*** :  식품
# Sub Category : 과일/견과 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G07&subGroupCode=S103
# ###########################################################################
# Sub Category : 쌀/잡곡 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G07&subGroupCode=S031
# ###########################################################################
# Sub Category : 축산 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G07&subGroupCode=S089
# ###########################################################################
# Sub Category : 수산 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G07&subGroupCode=S090
# ###########################################################################
# Sub Category : 김치/반찬 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G07&subGroupCode=S104
# ###########################################################################
# Sub Category : 생수/커피/음료 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G07&subGroupCode=S105
# ###########################################################################
# Sub Category : 간편조리/간식 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G07&subGroupCode=S106
# ###########################################################################
# Sub Category : 캔/오일/조미료 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G07&subGroupCode=S107
# ###########################################################################
# Sub Category : 건강 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G07&subGroupCode=S033
# ###########################################################################
# Sub Category : 다이어트 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G07&subGroupCode=S092
# ###########################################################################
# Sub Category : 정관장/홍삼 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G07&subGroupCode=S108
# ###########################################################################
# Sub Category : 채소 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G07&subGroupCode=S147
# ###########################################################################
# Sub Category : 홈플러스 식품 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G07&subGroupCode=S160
# ###########################################################################
# Sub Category :  Sub Category Link : http://corners.gmarket.co.kr//bestseller/BestSellerList.asp?group_kind=G&group_cd=G04&groupSub_kind=GS&groupSub_cd=S063
# ###########################################################################
# ***Main Category*** :  생활/주방/건강
# Sub Category : 생활용품 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G08&subGroupCode=S035
# ###########################################################################
# Sub Category : 주방용품 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G08&subGroupCode=S034
# ###########################################################################
# Sub Category : 세제/세면용품 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G08&subGroupCode=S066
# ###########################################################################
# Sub Category : 화장지/일용잡화 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G08&subGroupCode=S067
# ###########################################################################
# Sub Category : 위생용품 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G08&subGroupCode=S037
# ###########################################################################
# Sub Category : 취미/원예용품 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G08&subGroupCode=S038
# ###########################################################################
# Sub Category : 문구/사무용품 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G08&subGroupCode=S040
# ###########################################################################
# Sub Category : 반려동물용품 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G08&subGroupCode=S137
# ###########################################################################
# Sub Category : 공구설비/자재 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G08&subGroupCode=S145
# ###########################################################################
# Sub Category : 건강/의료용품 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G08&subGroupCode=S146
# ###########################################################################
# Sub Category : 홈플러스 리빙 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G08&subGroupCode=S159
# ###########################################################################
# Sub Category : 렌탈 서비스 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G08&subGroupCode=S173
# ###########################################################################
# ***Main Category*** :  가구/침구
# Sub Category : 가구 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G09&subGroupCode=S041
# ###########################################################################
# Sub Category : 침구 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G09&subGroupCode=S042
# ###########################################################################
# Sub Category : 커튼/블라인드 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G09&subGroupCode=S071
# ###########################################################################
# Sub Category : 홈패션/인테리어소품 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G09&subGroupCode=S043
# ###########################################################################
# Sub Category : 브랜드 가구/침구/인테리어 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G09&subGroupCode=S091
# ###########################################################################
# ***Main Category*** :  스포츠/자동차
# Sub Category : 레저 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G05&subGroupCode=S021
# ###########################################################################
# Sub Category : 스포츠 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G05&subGroupCode=S022
# ###########################################################################
# Sub Category : 골프 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G05&subGroupCode=S023
# ###########################################################################
# Sub Category : 스포츠/레저 브랜드 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G05&subGroupCode=S100
# ###########################################################################
# Sub Category : 자동차용품 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G05&subGroupCode=S024
# ###########################################################################
# ***Main Category*** :  컴퓨터/전자
# Sub Category : 노트북/태블릿 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G06&subGroupCode=S141
# ###########################################################################
# Sub Category : 모니터/프린터 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G06&subGroupCode=S140
# ###########################################################################
# Sub Category : 컴퓨터/용품 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G06&subGroupCode=S056
# ###########################################################################
# Sub Category : 대형가전 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G06&subGroupCode=S059
# ###########################################################################
# Sub Category : 저장장치  Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G06&subGroupCode=S138
# ###########################################################################
# Sub Category : 주방가전 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G06&subGroupCode=S142
# ###########################################################################
# Sub Category : 건강가전 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G06&subGroupCode=S139
# ###########################################################################
# Sub Category : 계절가전 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G06&subGroupCode=S061
# ###########################################################################
# Sub Category : 생활/미용가전 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G06&subGroupCode=S060
# ###########################################################################
# Sub Category : 카메라 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G06&subGroupCode=S057
# ###########################################################################
# Sub Category : 휴대폰 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G06&subGroupCode=S065
# ###########################################################################
# Sub Category : 헤드폰/이어폰 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G06&subGroupCode=S143
# ###########################################################################
# Sub Category : MP3/스피커 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G06&subGroupCode=S144
# ###########################################################################
# Sub Category : 게임 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G06&subGroupCode=S058
# ###########################################################################
# Sub Category : 디지털 액세서리 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G06&subGroupCode=S112
# ###########################################################################
# Sub Category : 컴퓨터 사업자몰 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G06&subGroupCode=S169
# ###########################################################################
# Sub Category : 하이마트 Sub Category Link : http://corners.gmarket.co.kr/http://minishop.gmarket.co.kr/ehimart1
# ###########################################################################
# ***Main Category*** :  도서/음반
# Sub Category : 시/소설 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G10&subGroupCode=S044
# ###########################################################################
# Sub Category : 경제/경영/개발 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G10&subGroupCode=S093
# ###########################################################################
# Sub Category : 인문/사회/과학/IT Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G10&subGroupCode=S094
# ###########################################################################
# Sub Category : 가정/생활/취미/레저 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G10&subGroupCode=S095
# ###########################################################################
# Sub Category : 만화/잡지 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G10&subGroupCode=S096
# ###########################################################################
# Sub Category : 해외원서 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G10&subGroupCode=S097
# ###########################################################################
# Sub Category : 학습/수험 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G10&subGroupCode=S045
# ###########################################################################
# Sub Category : 어린이 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G10&subGroupCode=S073
# ###########################################################################
# Sub Category : 음반 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G10&subGroupCode=S046
# ###########################################################################
# Sub Category : DVD Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G10&subGroupCode=S074
# ###########################################################################
# ***Main Category*** :  여행
# Sub Category : 국내여행 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G11&subGroupCode=S047
# ###########################################################################
# Sub Category : 해외여행 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G11&subGroupCode=S048
# ###########################################################################
# Sub Category : 여행소품 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G11&subGroupCode=S049
# ###########################################################################
# ***Main Category*** :  e쿠폰/티켓
# Sub Category : 외식 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G12&subGroupCode=S051
# ###########################################################################
# Sub Category : 온라인컨텐츠 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G12&subGroupCode=S052
# ###########################################################################
# Sub Category : 생활쿠폰 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G12&subGroupCode=S053
# ###########################################################################
# Sub Category : 상품권 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G12&subGroupCode=S148
# ###########################################################################
# Sub Category : 모바일 상품권 Sub Category Link : http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G12&subGroupCode=S135
# ###########################################################################

# %%
## main/sub category + 상품 정보 크롤링

def get_items(html, category_name, sub_category_name):
    items_result_list = list()
    best_item = html.select('div.best-list')
    for index,item in enumerate(best_item[1].select('li')):
        title = item.select_one('a.itemname').get_text()
        ori_price = item.select_one('div.o-price').get_text()
        dis_price = item.slect_one('div.s-price strong span').get_text()
        discount_percent = item.select_one('div.s-price em').get_text()


## main category 크롤링
res = requests.get('http://corners.gmarket.co.kr/Bestsellers') # base url
soup = BeautifulSoup(res.content, 'html.parser')

categories = soup.select('div.gbest-cate ul.by-group li a')

for category in categories:
    print("http://corners.gmarket.co.kr/" + category['href'], category.get_text())
    
## sub category 크롤링

def get_category(category_link, category_name):
    print(category_link, category_name) 
    res = requests.get(category_link)
    soup = BeautifulSoup(res.content, 'html.parser')
    
    sub_categories = soup.select('div.navi.group ul li a')
    for sub_category in sub_categories:
        print(category_link, category_name, sub_category.get_text(),"http://corners.gmarket.co.kr/" + sub_category['href'])

for category in categories:
    get_category("http://corners.gmarket.co.kr/" + category['href'], category.get_text())
