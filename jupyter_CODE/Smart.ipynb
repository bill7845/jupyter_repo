# %%
import os.path
import pandas as pd
import numpy as np
# import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
from sklearn import preprocessing

# %%
df_1 = []
df_2 = []

for i in range(1,10):
    tmp = pd.read_csv('./smartcarlog/SmartCarStatusInfo_2019070%d.txt' %i)
    df_1.append(tmp)

for j in range(10,32):
    tmp = pd.read_csv('./smartcarlog/SmartCarStatusInfo_201907%d.txt' %j)
    df_2.append(tmp)
# Out:
# C:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (0,2,3,4,5,6,7,8,9,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = df_1 + df_2

# %%
res_df = pd.concat(df,ignore_index=True)

# %%
res_df
# Out:
#          SmartCar Status Information CarNum TireFL TireFR TireBL TireBR  \
# 0                     20190701000000  L0001     94     84     85     87
# 1                     20190701000004  L0001     96     95    100     75
# 2                     20190701000008  L0001    100     92     92     95
# 3                     20190701000012  L0001     95     88     87     94
# 4                     20190701000016  L0001     94     73     90     90
# 5                     20190701000020  L0001     92     84     98     79
# 6                     20190701000024  L0001     83     73     89     80
# 7                     20190701000028  L0001     88     88     94     79
# 8                     20190701000032  L0001     72     90     86     77
# 9                     20190701000036  L0001     96    100     78     88
# 10                    20190701000040  L0001     95     97     79     83
# 11                    20190701000044  L0001     92    100     87     93
# ...

# %%
gr_1 = res_df.groupby(res_df['CarNum']).size()
gr_1
# Out:
# CarNum
# A0001    21601
# A0002    21601
# A0004    21601
# A0005    21601
# A0006    64803
# A0007    64803
# A0008    43202
# A0009    43202
# A0010    21601
# A0011    21601
# A0012    86404
# A0013    64803
# A0014    21601
# A0015    21601
# A0016    43202
# A0018    21601
# A0019    43202
# A0020    21601
# B0001    21601
# B0002    21601
# B0003    21601
# B0004    21601
# B0005    43202
# B0006    64803
# B0007    21601
# B0008    64803
# B0009    43202
# B0011    21601
# B0012    21601
# B0016    21601
#          ...
# Y0001    64803
# Y0002    43202
# Y0003    43202
# Y0005    21601
# Y0006    21601
# Y0008    64803
# Y0009    64803
# Y0010    21601
# Y0011    21601
# Y0012    86404
# Y0013    21601
# Y0015    43202
# Y0017    21601
# Y0018    21601
# Y0019    43202
# Y0020    21601
# Z0001    43202
# Z0002    21601
# Z0004    21601
# Z0006    21601
# Z0008    21601
# Z0009    43202
# Z0010    64803
# Z0011    21601
# Z0013    21601
# Z0014    86404
# Z0015    43202
# ...

# %%
df_master = pd.read_csv('./smartcarlog/CarMaster.txt',sep="|")
df_master
# Out:
#       A0001  여  32  미혼  서울  프리랜서  1000  2009  F
# 0     A0002  남  53  미혼  충남    주부  2500  2015  A
# 1     A0003  여  62  기혼  대전   회사원  2500  2012  B
# 2     A0004  남  31  미혼  광주   공무원  2000  2010  D
# 3     A0005  남  67  미혼  대구   공무원  1700  2002  C
# 4     A0006  여  30  미혼  인천   전문직  2000  2016  D
# 5     A0007  남  61  미혼  전남  개인사업  1700  2003  E
# 6     A0008  여  20  미혼  충북  개인사업  1500  2013  G
# 7     A0009  여  60  미혼  경남  프리랜서  3500  2015  D
# 8     A0010  여  69  미혼  제주  개인사업  1200  2003  A
# 9     A0011  남  29  기혼  충남    주부  1000  2008  G
# 10    A0012  여  53  미혼  세종    학생  2500  2006  E
# 11    A0013  여  43  미혼  인천   전문직  1500  2016  E
# 12    A0014  남  63  미혼  대구   공무원  1500  2006  C
# 13    A0015  남  45  미혼  충남  프리랜서  1700  2012  F
# 14    A0016  여  17  미혼  강원   회사원  2000  2001  G
# 15    A0017  남  48  미혼  충북  프리랜서  1000  2010  B
# 16    A0018  여  70  기혼  경북  개인사업  2000  2004  H
# 17    A0019  남  32  기혼  인천    주부  1700  2004  C
# 18    A0020  남  65  기혼  대구    주부  3500  2009  F
# ...

# %%
df_buy = pd.read_csv('./smartcarlog/CarItemBuyList_201606.txt')
df_buy
# Out:
#        M0014  Item-018  2  201606
# 0      G0035  Item-015  3  201606
# 1      I0090  Item-009  3  201606
# 2      K0095  Item-018  5  201606
# 3      Y0042  Item-020  2  201606
# 4      W0023  Item-030  2  201606
# 5      Y0036  Item-023  3  201606
# 6      T0026  Item-028  1  201606
# 7      Q0044  Item-008  1  201606
# 8      Q0056  Item-014  5  201606
# 9      N0095  Item-002  5  201606
# 10     M0051  Item-030  2  201606
# 11     D0021  Item-005  2  201606
# 12     B0084  Item-002  3  201606
# 13     I0085  Item-021  5  201606
# 14     L0066  Item-029  2  201606
# 15     T0082  Item-015  4  201606
# 16     Q0054  Item-027  5  201606
# 17     P0052  Item-011  2  201606
# 18     Y0086  Item-013  1  201606
# 19     T0060  Item-010  2  201606
# 20     X0016  Item-025  4  201606
# 21     P0004  Item-016  2  201606
# 22     X0037  Item-013  4  201606
# 23     O0083  Item-026  1  201606
# 24     P0008  Item-025  1  201606
# 25     Y0024  Item-019  4  201606
# ...
