# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

chromedriver = 'C:/selenium/chromedriver.exe'
driver = webdriver.Chrome(chromedriver)

user = input()

driver.get('https://brunch.co.kr/')

time.sleep(2)

hidden_submenu = driver.find_element_by_css_selector('#btnServiceMenuSearch')

actions = webdriver.ActionChains(driver)
actions.click(hidden_submenu)

actions.perform()

time.sleep(2)

user_search = driver.find_element_by_id("txt_search")

user_search.clear()
user_search.send_keys(user )

user_search.send_keys(Keys.RETURN)

time.sleep(2)

hidden_submenu1 = driver.find_element_by_css_selector('#resultArticle li:nth-child(1)') # 반복문 돌려야 할곳

actions = webdriver.ActionChains(driver)
actions.click(hidden_submenu1)

actions.perform()

driver.get('https://brunch.co.kr/@julien/231')
brunchs = driver.find_elements_by_tag_name("p")

for brunch in brunchs:
    print(brunch.text)
# Out:
# IT
#
#
# It 그것 (2017/2019)
# 'It' is a horror film based on Stephen King’s 1986 novel of the same name. The film tells the story of seven children who must face their fears and Pennywise, the killer clown.
# It 은 같은 제목의 스티븐 킹의 1986년 소설을 기반으로 한 공포 영화입니다. 이 영화는 살인자 광대인 페니와이즈와 그들의 공포에 맞서야 하는 일곱 명의 아이들에 대해 이야기합니다.
#
# * 원작자인 소설가 Stephen King 의 Stephen 은 '스티븐'으로 읽습니다. '스테판'이 아니에요.
#
# 영화에 대해 이야기할 때 보통 타입(type) 또는 장르(genre)부터 말하는 경우가 많죠. 영화의 장르에 대해 묻고 답해 보세요.
#
# A: What type of movie is 'John Wick'? '존 윅'은 어떤 종류의 영화야?
# B: It’s an action movie. 액션 영화야.
#
# 다양한 영화 장르
# horror 공포영화
# action 액션
# science fiction 공상과학
# adventure 모험
# comedy 코미디
# romance 로맨스
# documentary 다큐멘터리
# animation 애니메이션
# disaster 재난영화
# superhero 슈퍼히어로
# drama / historical drama 드라마 / 역사 드라마
# thriller 스릴러
#
# 한 영화가 여러 가지 복합적인 장르에 해당할 수도 있습니다. 예를 들어 초능력 주인공이 나오는 액션 애니메이션 영화라면, It’s a superhero action animation. 이라고 말할 수 있죠.
#
# Bill Skarsgard starred in the horror film ‘It’.
# 빌 스카스가드가 공포 영화 It 의 주연을 맡았습니다.
#
# 누가 어떤 영화나 연극 등에 출연한다고 할 때 동사 star 를 쓸 수 있습니다. 특히 주연이나 매우 비중 있는 역할을 맡는 경우에 쓰여요.
#
# 우리가 직접적으로 입에 담기 거북하거나, 간단히 표현하기 모호한 것을 에둘러서 ‘그것’이라고 말하듯, 이 영화 속에서 어린이를 잡아먹는 괴물 Pennywise 는 보통 it 으로 불립니다. 일단, 직접적으로 ‘괴물’ ‘살인자 광대’ 등으로 직접 말하는 것보다 도대체 ‘그것’이 무엇을 말하는 것인지 궁금증을 유발한다는 면에서 원작이나 영화의 제목 It 은 매우 효과적이죠.
#
# 그런데, 영어의 It 에는 ‘술래’라는 의미도 있습니다. ‘This time, you’re it.’이라고 하면 ‘이번엔 네가 술래야’라는 뜻이에요. 이 영화 속의 살인 괴물인 광대가 아이들을 잡아먹기 위해 쫓아다니는 것은 놀이에서 술래가 다른 사람들을 찾고 쫓아다니는 모습과 유사하죠. 원작자인 Stephen King 이 작품의 제목을 It 으로 한 데에는 분명 이런 의도도 숨겨져 있을 겁니다. 이렇게 영어에서는 영화나 작품의 제목뿐 아니라 상품명 등 다양한 곳에서 재치 있게 단어나 표현이 가진 여러 의미를 복합적으로 암시하는 ‘중의법(double entendre)’이 종종 사용됩니다.
#
# 말이 나온 김에 It 은 대화체에서 명사 앞에 붙어 매우 화제가 되거나 유행 중인 것을 나타내기도 합니다. 예를 들어 요즘 한창 유행하고 있는 가방이나 신발은 It-bag, It-shoes 라고 말할 수 있죠.
#
# Where can I buy an It-bag or It-shoes?
# 요즘 유행하는 가방이나 신발은 어디서 살 수 있죠?
#
# A: Who’s your favorite celebrity couple?
# 제일 좋아하는 유명인 커플이 누구니?
# B: Well, does royalty count as celebrities? Then I guess Prince William and Kate. How about you? Which It-couple do you like best?
# 글쎄, 왕족도 유명인에 들어가나? 그렇다면 윌리엄 왕자와 케이트 같아. 너는? 어떤 유명인 커플을 제일 좋아하니?
# A: Brad Pitt and Angelina Jolie used to be my favorite It-couple, but now they’re not together anymore, I’ll give my vote to Ben Affleck and Jennifer Garner.
# 브래드 피트와 안젤리나 졸리가 나의 최애 ‘잇’ 커플이었는데, 이제 그들이 더 이상 함께가 아니니까, 벤 에플렉과 제니퍼 가너에게 한 표를 주겠어.
# B: Hey. They’re not a couple anymore, either. They got divorced.
# 이봐, 그들도 더 이상 커플이 아냐. 이혼했어.
# A: What? Really? When?
# 뭐? 정말? 언제?
# B: In 2018, as far as I remember.
# 내가 기억하기로는 2018년이야.
# 유튜브(Youtube)에서 영화 It(2017)의 후속편이라 할 수 있는 It: Chater Two 의 official trailer(예고편)를 즐겨 보세요.
# https://www.youtube.com/watch?v=zqUopiAYdRg
# None
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-20-eabc6306aeaf> in <module>
#      41
#      42 for brunch in brunchs:
# ---> 43     print(brunch.text)
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in text(self)
#      74     def text(self):
#      75         """The text of the element."""
# ---> 76         return self._execute(Command.GET_ELEMENT_TEXT)['value']
#      77
#      78     def click(self):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=77.0.3865.120)
