# %%
##############################################
# Modeling    
##############################################
from keras import layers, models
from sklearn import preprocessing

def ANN_seq_func(Nin, Nh, Nout):
    model = #TODO
    """ Keras 모델 시작 """

    model.#TODO 
    """입력 계층 노드 수 Nin 개,  은닉 계층의 노드 수 Nh 개, 활성함수는 relu  """

    model.#TODO
    """출력 노드 수 Nout 개,  활성함수는  relu) """

    model.#TODO
    """ cost함수 - mse – 평균 제곱 오차  최적화  알고리즘 -SGD(확률적 경사하강법) 
    """

    return model

# %%
##############################################
# Data  학습과 평가용 데이터 불러오기 
##############################################
from keras import datasets

def Data_func():  
    (X_train, y_train), (X_test, y_test) = datasets#TODO 
    scaler = #TODO   # 데이터 정규화  
    X_train = #TODO 
    X_test = #TODO 
    print (X_train.shape, y_train.shape )
    
    return (X_train, y_train), (X_test, y_test)
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From A:\Python\Anaconda3.5\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# (404, 13) (404,)
# WARNING:tensorflow:From A:\Python\Anaconda3.5\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 323 samples, validate on 81 samples
# Epoch 1/100
#  - 1s - loss: 507.5962 - val_loss: 139.5478
# Epoch 2/100
#  - 0s - loss: 107.4867 - val_loss: 91.8360
# Epoch 3/100
#  - 0s - loss: 85.3652 - val_loss: 76.4735
# Epoch 4/100
#  - 0s - loss: 69.6979 - val_loss: 76.9447
# Epoch 5/100
#  - 0s - loss: 61.4406 - val_loss: 58.4864
# Epoch 6/100
#  - 0s - loss: 60.4331 - val_loss: 72.3975
# Epoch 7/100
#  - 0s - loss: 86.8619 - val_loss: 53.5747
# Epoch 8/100
#  - 0s - loss: 49.4989 - val_loss: 95.5240
# Epoch 9/100
#  - 0s - loss: 66.0022 - val_loss: 63.5295
# Epoch 10/100
#  - 0s - loss: 48.1617 - val_loss: 51.6457
# Epoch 11/100
#  - 0s - loss: 42.4860 - val_loss: 47.7609
# Epoch 12/100
#  - 0s - loss: 40.9623 - val_loss: 39.9153
# Epoch 13/100
#  - 0s - loss: 38.1933 - val_loss: 58.5686
# Epoch 14/100
#  - 0s - loss: 48.3012 - val_loss: 48.4246
# Epoch 15/100
#  - 0s - loss: 50.5731 - val_loss: 49.6887
# Epoch 16/100
#  - 0s - loss: 36.6203 - val_loss: 49.6552
# Epoch 17/100
#  - 0s - loss: 35.1853 - val_loss: 36.0302
# Epoch 18/100
#  - 0s - loss: 33.0377 - val_loss: 43.4061
# Epoch 19/100
#  - 0s - loss: 33.2982 - val_loss: 35.0145
# Epoch 20/100
#  - 0s - loss: 30.4321 - val_loss: 29.8958
# Epoch 21/100
#  - 0s - loss: 29.2108 - val_loss: 30.8602
# Epoch 22/100
#  - 0s - loss: 28.4583 - val_loss: 38.4090
# Epoch 23/100
#  - 0s - loss: 32.9632 - val_loss: 40.2715
# Epoch 24/100
#  - 0s - loss: 34.6851 - val_loss: 35.4651
# Epoch 25/100
#  - 0s - loss: 33.6247 - val_loss: 45.8549
# Epoch 26/100
#  - 0s - loss: 58.5664 - val_loss: 57.5482
# Epoch 27/100
#  - 0s - loss: 39.5209 - val_loss: 27.8779
# Epoch 28/100
#  - 0s - loss: 26.8976 - val_loss: 25.4098
# Epoch 29/100
#  - 0s - loss: 25.9572 - val_loss: 34.3427
# Epoch 30/100
#  - 0s - loss: 41.9976 - val_loss: 27.0214
# Epoch 31/100
#  - 0s - loss: 28.3931 - val_loss: 58.1924
# Epoch 32/100
#  - 0s - loss: 48.2127 - val_loss: 24.4587
# Epoch 33/100
#  - 0s - loss: 35.1392 - val_loss: 52.3308
# Epoch 34/100
#  - 0s - loss: 59.8607 - val_loss: 38.5386
# Epoch 35/100
#  - 0s - loss: 38.4624 - val_loss: 47.6864
# Epoch 36/100
#  - 0s - loss: 37.7336 - val_loss: 62.0718
# Epoch 37/100
#  - 0s - loss: 79.6539 - val_loss: 25.3551
# Epoch 38/100
#  - 0s - loss: 25.5145 - val_loss: 25.6345
# Epoch 39/100
#  - 0s - loss: 26.2216 - val_loss: 24.2479
# Epoch 40/100
#  - 0s - loss: 28.1125 - val_loss: 24.4363
# Epoch 41/100
#  - 0s - loss: 24.6897 - val_loss: 26.3662
# Epoch 42/100
#  - 0s - loss: 26.8790 - val_loss: 24.9779
# Epoch 43/100
#  - 0s - loss: 24.7315 - val_loss: 31.4385
# Epoch 44/100
#  - 0s - loss: 29.0180 - val_loss: 26.8399
# Epoch 45/100
#  - 0s - loss: 32.6163 - val_loss: 41.1717
# Epoch 46/100
#  - 0s - loss: 36.5088 - val_loss: 25.4506
# Epoch 47/100
#  - 0s - loss: 26.0620 - val_loss: 51.3936
# Epoch 48/100
#  - 0s - loss: 42.7924 - val_loss: 42.6289
# Epoch 49/100
#  - 0s - loss: 28.3340 - val_loss: 26.2688
# Epoch 50/100
#  - 0s - loss: 24.7235 - val_loss: 37.3182
# Epoch 51/100
#  - 0s - loss: 42.0613 - val_loss: 23.2147
# Epoch 52/100
#  - 0s - loss: 23.8612 - val_loss: 25.1524
# Epoch 53/100
#  - 0s - loss: 29.9733 - val_loss: 49.8762
# Epoch 54/100
#  - 0s - loss: 31.4970 - val_loss: 49.3306
# Epoch 55/100
#  - 0s - loss: 38.8016 - val_loss: 77.6347
# Epoch 56/100
#  - 0s - loss: 47.8754 - val_loss: 55.4240
# Epoch 57/100
#  - 0s - loss: 37.1704 - val_loss: 24.4252
# Epoch 58/100
#  - 0s - loss: 23.8952 - val_loss: 22.8356
# Epoch 59/100
#  - 0s - loss: 23.7009 - val_loss: 27.8069
# Epoch 60/100
#  - 0s - loss: 24.8271 - val_loss: 43.0857
# Epoch 61/100
#  - 0s - loss: 30.0213 - val_loss: 25.4814
# Epoch 62/100
#  - 0s - loss: 23.9947 - val_loss: 24.6982
# Epoch 63/100
#  - 0s - loss: 32.6793 - val_loss: 22.8031
# Epoch 64/100
#  - 0s - loss: 23.1965 - val_loss: 27.1300
# Epoch 65/100
#  - 0s - loss: 34.2356 - val_loss: 38.7460
# Epoch 66/100
#  - 0s - loss: 40.9803 - val_loss: 23.7091
# Epoch 67/100
#  - 0s - loss: 28.8276 - val_loss: 25.3921
# Epoch 68/100
#  - 0s - loss: 26.6247 - val_loss: 22.4025
# Epoch 69/100
#  - 0s - loss: 23.7414 - val_loss: 22.3074
# Epoch 70/100
#  - 0s - loss: 22.9868 - val_loss: 22.5071
# Epoch 71/100
#  - 0s - loss: 25.2780 - val_loss: 21.9121
# Epoch 72/100
#  - 0s - loss: 25.7562 - val_loss: 23.4008
# Epoch 73/100
#  - 0s - loss: 23.0478 - val_loss: 24.8658
# Epoch 74/100
#  - 0s - loss: 25.8585 - val_loss: 40.1482
# Epoch 75/100
#  - 0s - loss: 31.7529 - val_loss: 27.4087
# Epoch 76/100
#  - 0s - loss: 25.1744 - val_loss: 23.5315
# Epoch 77/100
#  - 0s - loss: 29.1151 - val_loss: 24.6805
# Epoch 78/100
#  - 0s - loss: 24.5181 - val_loss: 21.5987
# Epoch 79/100
#  - 0s - loss: 23.1689 - val_loss: 21.7161
# Epoch 80/100
#  - 0s - loss: 23.6513 - val_loss: 24.3512
# Epoch 81/100
#  - 0s - loss: 28.8941 - val_loss: 34.4527
# Epoch 82/100
#  - 0s - loss: 38.7335 - val_loss: 22.9911
# Epoch 83/100
#  - 0s - loss: 23.4583 - val_loss: 22.2652
# Epoch 84/100
#  - 0s - loss: 23.2851 - val_loss: 28.1643
# Epoch 85/100
#  - 0s - loss: 29.7357 - val_loss: 21.6752
# Epoch 86/100
#  - 0s - loss: 26.5299 - val_loss: 30.1414
# Epoch 87/100
#  - 0s - loss: 36.1335 - val_loss: 41.6135
# Epoch 88/100
#  - 0s - loss: 33.6007 - val_loss: 21.5048
# Epoch 89/100
#  - 0s - loss: 22.6185 - val_loss: 23.2900
# Epoch 90/100
#  - 0s - loss: 22.6898 - val_loss: 22.0753
# Epoch 91/100
#  - 0s - loss: 25.2127 - val_loss: 25.6148
# Epoch 92/100
#  - 0s - loss: 23.3690 - val_loss: 21.8198
# Epoch 93/100
#  - 0s - loss: 22.7518 - val_loss: 24.5427
# Epoch 94/100
#  - 0s - loss: 22.3997 - val_loss: 27.9916
# Epoch 95/100
#  - 0s - loss: 22.4784 - val_loss: 21.0087
# Epoch 96/100
#  - 0s - loss: 22.5838 - val_loss: 20.8060
# Epoch 97/100
#  - 0s - loss: 23.1519 - val_loss: 23.0759
# Epoch 98/100
#  - 0s - loss: 23.0991 - val_loss: 23.9997
# Epoch 99/100
#  - 0s - loss: 22.5450 - val_loss: 26.7308
# Epoch 100/100
#  - 0s - loss: 26.7466 - val_loss: 34.0147
# 102/102 [==============================] - 0s 39us/step
#
# Test Loss -> 31.89

# %%
##############################################
# Plotting  결과 그래프 구현 
##############################################
import matplotlib.pyplot as plt
# %matplotlib inline 

##############################################
# Main  회귀 ANN 학습 및 성능 분석 
##############################################
def main():
    Nin = 13
    Nh = 5
    Nout = 1

    model = ANN_seq_func(Nin, Nh, Nout)
    (X_train, y_train), (X_test, y_test) =  #TODO 
    
    history =  #TODO 
    
    performace_test =  #TODO 
    print('\nTest Loss -> {:.2f}'.format(performace_test))

    
    history = #TODO  
    """Cost/Loss  변화 추이 그래프"""
    plt.plot(#TODO )
    plt.plot(#TODO )
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Training', 'Verification'], loc=0)
    plt.show()


if __name__ == '__main__':
    main()
