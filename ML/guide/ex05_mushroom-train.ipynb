# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.model_selection import train_test_split 

# 데이터 읽어 들이기 
mr = #TODO 
# 데이터 내부의 기호를 숫자로 변환 )
label = []
data = []
attr_list = []
for row_index, row in #TODO 
    label.#TODO
    row_data = []
    for v in row.iloc[1:]:
        row_data.#TODO
    data.append(row_data)
    
# 학습 전용과 테스트 전용 데이터로 나누기
data_train, data_test, label_train, label_test = #TODO

# 데이터 학습시키기  
clf = #TODO
clf.#TODO

# 데이터 예측하기 
predict = clf.#TODO 

# 결과 테스트하기 -
ac_score = metrics.#TODO
cl_report = metrics.#TODO
print("정답률 =", ac_score)
print("리포트 =\n", cl_report)
# Out:
# 정답률 = 1.0
# 리포트 =
#                precision    recall  f1-score   support
#
#            e       1.00      1.00      1.00      1045
#            p       1.00      1.00      1.00       986
#
#    micro avg       1.00      1.00      1.00      2031
#    macro avg       1.00      1.00      1.00      2031
# weighted avg       1.00      1.00      1.00      2031
# A:\Python\Anaconda3_201903\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
