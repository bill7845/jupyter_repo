# %%
import pandas as pd
import json
import os

# %%
with open('C:/Users/KIHyuk/Desktop/brunch_data/json/건축·설계.json',encoding='UTF8') as json_file:
    json_data = json.load(json_file)

# %%
json_data.keys()
# Out:
# dict_keys(['name', 'version', 'data'])

# %%
# data :
# 'title', 'nickname', 'publish_date', 'keyword[]', 'like', 'share', 'comment', 'url', 'url_plink', 'text[]'

# %%
df = pd.DataFrame(json_data['data'],
                  columns=['title','keyword','text','nickname','publish_date','likes','share','comment','url','url_plink'])

# %%
df.head(5)
# Out:
#                             title            keyword  \
# 0             나이 서른, 다시 나를 고민한다.        [건축, 생각, 나이]
# 1  광주광역시 남구 최**님 전원주택기초 타설 완료 4/1  [홈트리오, 건축가, 전원주택]
# 2                      고용산재보험 신청기  [산재보험, 전원주택, 집짓기]
# 3              프로들의 표정엔 자부심이 묻어난다    [한옥대수선, 한옥, 건축]
# 4              정크스페이스 바이러스에 감염되다!       [북, 건축, 디자인]
#
#                                                 text      nickname  \
# 0  ['굴곡이 많은 삶을 나름대로 잘 살아왔다고 생각했다. 왜냐하면 그 굴곡의 대부분은...         건축고구마
# 1  ['안녕하세요. 홈트리오(주) 이동혁 건축가입니다.^^', '', '광주광역시 남구...  이동혁 건축가o홈트리오
# 2  ['우리집은 직영공사의 형태로 짓는다. 직영공사이므로, 공사기간 중 보험처리는 건축...          Emma
# 3  ['2020.03.31(화) 공사\xa018일\xa0차', '어제부터\xa0미장\x...        소행성 쌔비
# 4  ['', '“스페이스 정크 space-junk가 우주에 버린 인간의 쓰레기라면, 정...         파리지언니
#
#             publish_date  likes share comment  \
# 0  2020-04-01T17:50+0900    NaN  None    None
# 1  2020-04-01T17:24+0900    NaN     1    None
# 2  2020-04-01T14:19+0900    NaN  None    None
# 3  2020-04-01T05:12+0900    NaN    41       4
# 4  2020-04-01T01:53+0900    NaN     1    None
#
#                                    url                        url_plink
# 0      https://brunch.co.kr/@psy8846/1    https://brunch.co.kr/@@9Nqm/1
# 1   https://brunch.co.kr/@sunsutu/1390  https://brunch.co.kr/@@3xR/1390
# 2  https://brunch.co.kr/@emmagarden/23    https://brunch.co.kr/@@2Lz/23
# 3   https://brunch.co.kr/@savvyoon/529   https://brunch.co.kr/@@7sW/529
# 4      https://brunch.co.kr/@chiyj/102  https://brunch.co.kr/@@2rnv/102

# %% [markdown]
# ## preprocessing

# %%
# text nan 개수
print("text nan 제거 전 : ",len(df))
print("text nan인 경우 : ",df['text'].isnull().sum())

# text nan 제거
df = df.dropna(subset=['text'])

print("text nan 제거 후 : ",len(df))
# Out:
# text nan 제거 전 :  2275
# text nan인 경우 :  1
# text nan 제거 후 :  2274

# %%
# keyword 
def pre_keyword(x):
    tmp = []
    for val in x:
        tmp.append(val.replace("\n","").replace(" ",""))
    return tmp

df['keyword'] = df['keyword'].apply(pre_keyword)

df['keyword'][0]
# Out:
# ['건축', '생각', '나이']

# %%
def pre_comment(x):
    if len(x) == 0:
        return None
    else :
        return x

df['comment'] = df['comment'].apply(pre_comment)

# %%
def pre_text(x):
    return str(x)

df['text'] = df['text'].apply(pre_text)

# %%
df
# Out:
#                                title            keyword  \
# 0                나이 서른, 다시 나를 고민한다.        [건축, 생각, 나이]
# 1     광주광역시 남구 최**님 전원주택기초 타설 완료 4/1  [홈트리오, 건축가, 전원주택]
# 2                         고용산재보험 신청기  [산재보험, 전원주택, 집짓기]
# 3                 프로들의 표정엔 자부심이 묻어난다    [한옥대수선, 한옥, 건축]
# 4                 정크스페이스 바이러스에 감염되다!       [북, 건축, 디자인]
# ...                              ...                ...
# 2270                     2013-경계의 건축  [건축디자인, 건축가, 디자인]
# 2271                 2013-안도 다다오의 건축  [건축디자인, 건축가, 디자인]
# 2272                          그림 그리기     [그림, life, 건축]
# 2273                         미술관의 탄생    [유럽여행, 건축, 미술관]
# 2274            30년 후 최고의 직업은 무엇일까요?    [건축, 콘크리트, 아파트]
#
#                                                    text        nickname  \
# 0     ['굴곡이 많은 삶을 나름대로 잘 살아왔다고 생각했다. 왜냐하면 그 굴곡의 대부분은...           건축고구마
# 1     ['안녕하세요. 홈트리오(주) 이동혁 건축가입니다.^^', '', '광주광역시 남구...    이동혁 건축가o홈트리오
# 2     ['우리집은 직영공사의 형태로 짓는다. 직영공사이므로, 공사기간 중 보험처리는 건축...            Emma
# 3     ['2020.03.31(화) 공사\xa018일\xa0차', '어제부터\xa0미장\x...          소행성 쌔비
# 4     ['', '“스페이스 정크 space-junk가 우주에 버린 인간의 쓰레기라면, 정...           파리지언니
# ...                                                 ...             ...
# 2270  ['2013-경계의 건축', '', '태평양 연안을 중심으로 발생했던 모더니즘 건축...             백건우
# 2271  ['2013-안도 다다오의 건축', '', '안도 다다오와 그의 건축에 관한 다큐멘...             백건우
# 2272  ['\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0...             이경희
# 2273  ['\xa0\xa0한 미술관에 가면 일단 우리는 그 안에서 수많은 작품을 만나게 된...  Storytraveller
# 2274  ["다는 아닐지라도 \xa0연예인, 뮤지컬 배우, 가수, 댄서 등 예능 쪽이 대세입...             조원용
#
#                publish_date  likes  share comment  \
# 0     2020-04-01T17:50+0900    NaN   None    None
# 1     2020-04-01T17:24+0900    NaN      1    None
# 2     2020-04-01T14:19+0900    NaN   None    None
# 3     2020-04-01T05:12+0900    NaN     41       4
# 4     2020-04-01T01:53+0900    NaN      1    None
# ...                     ...    ...    ...     ...
# 2270  2015-10-01T22:37+0900    NaN      8    None
# 2271  2015-10-01T17:29+0900    NaN     21    None
# 2272  2015-09-30T22:45+0900    NaN   None       2
# 2273  2015-09-16T21:34+0900    NaN     37       2
# 2274  2015-08-16T01:00+0900    NaN  6,114      81
#
#                                       url                        url_plink
# 0         https://brunch.co.kr/@psy8846/1    https://brunch.co.kr/@@9Nqm/1
# 1      https://brunch.co.kr/@sunsutu/1390  https://brunch.co.kr/@@3xR/1390
# 2     https://brunch.co.kr/@emmagarden/23    https://brunch.co.kr/@@2Lz/23
# 3      https://brunch.co.kr/@savvyoon/529   https://brunch.co.kr/@@7sW/529
# 4         https://brunch.co.kr/@chiyj/102  https://brunch.co.kr/@@2rnv/102
# ...                                   ...                              ...
# 2270  https://brunch.co.kr/@marupress/103   https://brunch.co.kr/@@3xO/103
# 2271  https://brunch.co.kr/@marupress/102   https://brunch.co.kr/@@3xO/102
# 2272    https://brunch.co.kr/@khlee5343/9     https://brunch.co.kr/@@sBw/9
# 2273      https://brunch.co.kr/@dn5445/32    https://brunch.co.kr/@@38q/32
# 2274     https://brunch.co.kr/@archicwy/1     https://brunch.co.kr/@@eos/1
#
# [2274 rows x 10 columns]
