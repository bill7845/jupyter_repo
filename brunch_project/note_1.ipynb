# %%
import pandas as pd
import json
import os

# %%
with open('C:/Users/KIHyuk/Desktop/brunch_data/json/멋진_캘리그래피.json',encoding='UTF8') as json_file:
    json_data = json.load(json_file)

# %%
json_data.keys()
# Out:
# dict_keys(['name', 'version', 'data'])

# %%
# data :
# 'title', 'nickname', 'publish_date', 'keyword[]', 'like', 'share', 'comment', 'url', 'url_plink', 'text[]'

# %%
df = pd.DataFrame(json_data['data'],
                  columns=['title','keyword','text','nickname','publish_date','likes','share','comment','url','url_plink'])

# %%
df.head(5)
# Out:
#                  title                                            keyword  \
# 0                   4월  [캘리에세이\n                        , 캘리그라피\n     ...
# 1  취미가 기적이 되던 그 처음의 순간  [1인기업\n                        , 캘리그래피\n      ...
# 2            이어즈 앤 이어즈  [SF\n                        , 손글씨\n          ...
# 3  마지막화_ 여행길에서 이름 주고받기  [멕시코\n                        , 캘리그라피\n       ...
# 4             4월 - 나태주  [나태주\n                        , 손글씨\n         ...
#
#                                                 text          nickname  \
# 0  [, , , 날도 좋고 나도 좋고오늘따라 더 보고싶으니까 괜히 날씨 핑계삼아 전화해...  캘리에세이 CALLIESSAY
# 1  [, 나는 사람들에게 , 취미가 기적이 되는 삶을 살고 전하는 , 취미 기적 메신저...                소담
# 2  ['이어즈 앤 이어즈'는 영국의 한 가정을 중심으로 2019년부터 2034년까지의 ...                양보
# 3  [해당 이야기는 워크어웨이(Workaway)를 통해 다녀온 여행 에세이를 담고 있습...            사람 여행자
# 4  [4월 - 나태주, <너만 모르는 그리움>, , , #손글씨 , #필사 , #또박또...                꿈보
#
#             publish_date  likes share comment  \
# 0  2020-04-01T23:54+0900    NaN  None
# 1  2020-04-01T18:33+0900    NaN  None
# 2  2020-04-01T15:17+0900    NaN  None
# 3  2020-04-01T13:16+0900    NaN  None
# 4  2020-04-01T12:38+0900    NaN  None
#
#                                         url                        url_plink
# 0       https://brunch.co.kr/@calliessay/90    https://brunch.co.kr/@@sUs/90
# 1        https://brunch.co.kr/@sodamday/132   https://brunch.co.kr/@@jUs/132
# 2        https://brunch.co.kr/@prorange/648   https://brunch.co.kr/@@4D6/648
# 3  https://brunch.co.kr/@yoonistraveling/70   https://brunch.co.kr/@@5CEG/70
# 4    https://brunch.co.kr/@eunjeong-wui/243  https://brunch.co.kr/@@4RHK/243

# %% [markdown]
# ## preprocessing

# %%
# text nan 개수
print("text nan 제거 전 : ",len(df))
print("text nan인 경우 : ",df['text'].isnull().sum())

# text nan 제거
df = df.dropna(subset=['text'])

print("text nan 제거 후 : ",len(df))
# Out:
# text nan 제거 전 :  3587
# text nan인 경우 :  84
# text nan 제거 후 :  3503

# %%
# keyword 
def pre_keyword(x):
    tmp = []
    for val in x:
        tmp.append(val.replace("\n","").replace(" ",""))
    return tmp

df['keyword'] = df['keyword'].apply(pre_keyword)

df['keyword'][0]
# Out:
# ['캘리에세이', '캘리그라피', '4월']

# %%
def pre_comment(x):
    if len(x) == 0:
        return None
    else :
        return x

df['comment'] = df['comment'].apply(pre_comment)

# %%
def pre_text(x):
    return str(x)

df['text'] = df['text'].apply(pre_text)

# %%
df
# Out:
#                     title              keyword  \
# 0                      4월   [캘리에세이, 캘리그라피, 4월]
# 1     취미가 기적이 되던 그 처음의 순간    [1인기업, 캘리그래피, 시작]
# 2               이어즈 앤 이어즈       [SF, 손글씨, 드라마]
# 3     마지막화_ 여행길에서 이름 주고받기  [멕시코, 캘리그라피, 감성에세이]
# 4                4월 - 나태주       [나태주, 손글씨, 필사]
# ...                   ...                  ...
# 3582             어떻게 지냈어?        [일상, 안부, 손글씨]
# 3583        너에게 말한다. 틀렸어!      [캘리그래피, 시, 에세이]
# 3584       I'm not loser.         [손글씨, 꿈, 현실]
# 3585         내 맘대로 손, 글쓰기     [일상, 손글씨, 감성에세이]
# 3586           03화 소중한 날들      [에세이, 디자인, 손글씨]
#
#                                                    text          nickname  \
# 0     ['', '', '', '날도 좋고 나도 좋고오늘따라 더 보고싶으니까\xa0괜히 날...  캘리에세이 CALLIESSAY
# 1     ['', '나는 사람들에게 ', '취미가 기적이 되는 삶을 살고 전하는 ', '취미...                소담
# 2     ["'이어즈 앤 이어즈'는 영국의 한 가정을 중심으로 2019년부터 2034년까지의...                양보
# 3     ['해당 이야기는 워크어웨이(Workaway)를 통해 다녀온 여행 에세이를 담고 있...            사람 여행자
# 4     ['4월 - 나태주', '<너만 모르는 그리움>', '', '', '#손글씨 , #...                꿈보
# ...                                                 ...               ...
# 3582  ['', '누군가를 만났을때-', "'잘'지내냐고 묻지 않기로 했다.", '꼭 잘 ...                양보
# 3583  ['', '틀렸다와 다르다의 차이는 여러 책들과 강연 등을 통해서 확실히 구분 지어...                숨빛
# 3584  ['스물여덞 하고도 절반이 지난가을에 사표를 냈다. 출판부서로 옮긴 지 일 년 만이...                양보
# 3585  ['\xa0\xa0선물을 할 때 나는 되도록이면 편지를 함께 주려고 노력한다.', ...                양보
# 3586  ["아이들과 함께 할 수 있는 시간이 얼마 안남았다는 것을 생각하게 된\xa0건 큰...               우연주
#
#                publish_date  likes share comment  \
# 0     2020-04-01T23:54+0900    NaN  None    None
# 1     2020-04-01T18:33+0900    NaN  None    None
# 2     2020-04-01T15:17+0900    NaN  None    None
# 3     2020-04-01T13:16+0900    NaN  None    None
# 4     2020-04-01T12:38+0900    NaN  None    None
# ...                     ...    ...   ...     ...
# 3582  2015-07-26T13:33+0900    NaN  None       2
# 3583  2015-07-16T14:30+0900    NaN    27       4
# 3584  2015-07-13T10:33+0900    NaN    22      17
# 3585  2015-07-10T16:26+0900    NaN     1       6
# 3586  2015-06-27T12:55+0900    NaN     5    None
#
#                                            url  \
# 0          https://brunch.co.kr/@calliessay/90
# 1           https://brunch.co.kr/@sodamday/132
# 2           https://brunch.co.kr/@prorange/648
# 3     https://brunch.co.kr/@yoonistraveling/70
# 4       https://brunch.co.kr/@eunjeong-wui/243
# ...                                        ...
# 3582         https://brunch.co.kr/@prorange/15
# 3583         https://brunch.co.kr/@chancalli/7
# 3584          https://brunch.co.kr/@prorange/4
# 3585          https://brunch.co.kr/@prorange/1
# 3586             https://brunch.co.kr/@yjwoo/4
#
#                             url_plink
# 0       https://brunch.co.kr/@@sUs/90
# 1      https://brunch.co.kr/@@jUs/132
# 2      https://brunch.co.kr/@@4D6/648
# 3      https://brunch.co.kr/@@5CEG/70
# 4     https://brunch.co.kr/@@4RHK/243
# ...                               ...
# 3582    https://brunch.co.kr/@@4D6/15
# 3583     https://brunch.co.kr/@@7tU/7
# 3584     https://brunch.co.kr/@@4D6/4
# 3585     https://brunch.co.kr/@@4D6/1
# 3586     https://brunch.co.kr/@@3hA/4
#
# [3503 rows x 10 columns]
